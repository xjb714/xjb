# %% [markdown]
# Before reading this document, you need to first read the paper "fast_f2s.pdf".
# Install the Jupyter plugin in VSCode and install the Python runtime dependencies using the command `pip3 install ipykernel`.
# This document is intended to assist you in understanding the c/c++ code implementation.
#
# Since float can be proven through exhaustive testing, this document only covers double-precision floating-point numbers. The exhaustive test for single-precision floating-point numbers is conducted in main.cpp within the function "check_all_float_number();".
#
# Printing a floating-point number involves two steps. The first step is to convert the floating-point number to decimal, and the second step is to convert the decimal to ASCII. First, let me introduce the first step.
#
# xjb64_i.cpp implements the conversion of floating-point numbers to decimal values that comply with the Steele and White principles.
# xjb64_f64_to_dec() is the main function that converts a floating-point number to a decimal value.
# This function only processes positive floating-point numbers. Does not include 0 or NaN or Inf.

# %%
static inline void xjb64_f64_to_dec(double v,unsigned long long* dec,int *e10)
{
    unsigned long long vi = *(unsigned  long long*)&v;
    unsigned long long sig = vi & ((1ull<<52) - 1);
    unsigned long long exp = (vi << 1 ) >> 53;

    typedef __uint128_t u128;
    typedef uint64_t u64;
    uint64_t c;
    int32_t q;
    u64 ieee_significand = sig;
    u64 ieee_exponent = exp;

#ifdef __amd64__
    if (ieee_exponent > 0) [[likely]] // branch
    {
        c = (1ull<<52) | ieee_significand;// 53 bit
        q = ieee_exponent - 1075;
    }
    else
    {
        c = ieee_significand;
        q = 1 - 1075; // -1074
    }
#else
    c = (ieee_exponent > 0) ? ( (1ull<<52) | ieee_significand) : ieee_significand;
    q = (ieee_exponent > 0) ? (ieee_exponent - 1075) : 1-1075;
#endif

    // v = c * 2**q
    // c * 2**q * 10**(-k-1) = m + n
    // m = floor( c * 2**q * 10**(-k-1) )
    // n = fractional part
    // convert c * 2**q  to d * 10**k
    // ten = 10m
    // select  from  {ten + 0, ten + floor(10n) , ten + floor(10n) + 1 , ten + 10}

    int k;
    const int offset = 6; // [5,10] ; 5 + 64 >= 69    6+64=70 >=69
    u64 regular = ieee_significand > 0;
    u64 irregular = (ieee_significand == 0);
    static const uint64_t bitarray_irregular[32] = {
    0x0000000000010040, 0x0000000000000004, 0x0000000000000000, 0x0020090000000000,
    0x0000000000000000, 0x0000000000000100, 0x0000000000000000, 0x0000000000000000,
    0x0000000000400000, 0x0000000000000000, 0x0000000000020000, 0x0000000000800000,
    0x0000000000000000, 0x0008000000000000, 0x0004000040000000, 0x0000000000000000,
    0x0000000000000000, 0x0000000001000000, 0x0020000000000000, 0x0000000000000000,
    0x0001000000040000, 0x0200000001000000, 0x0000000000102000, 0x0000000100000000,
    0x2000000000000000, 0x0000000000020000, 0x0000000000000000, 0x0000000000000000,
    0x0000000000000000, 0x0000000040000000, 0x0000000000000000, 0x0000000000008000};
    static const u64 g[(323 - (-293) + 1) * 2] = {
        0xcc5fc196fefd7d0c, 0x1e53ed49a96272c9, // -293
        0xff77b1fcbebcdc4f, 0x25e8e89c13bb0f7b, // -292
        0x9faacf3df73609b1, 0x77b191618c54e9ad, // -291
        0xc795830d75038c1d, 0xd59df5b9ef6a2418, // -290
        0xf97ae3d0d2446f25, 0x4b0573286b44ad1e, // -289
        0xdbe6fecebdedd5be, 0xb573440e5a884d1c, // -10
        0x89705f4136b4a597, 0x31680a88f8953031, // -9
        0xabcc77118461cefc, 0xfdc20d2b36ba7c3e, // -8
        0xd6bf94d5e57a42bc, 0x3d32907604691b4d, // -7
        0x8637bd05af6c69b5, 0xa63f9a49c2c1b110, // -6
        0xa7c5ac471b478423, 0xfcf80dc33721d54,  // -5
        0xd1b71758e219652b, 0xd3c36113404ea4a9, // -4
        0x83126e978d4fdf3b, 0x645a1cac083126ea, // -3
        0xa3d70a3d70a3d70a, 0x3d70a3d70a3d70a4, // -2
        0xcccccccccccccccc, 0xcccccccccccccccd, // -1
        0x8000000000000000, 0x0,                // 0
        0xa000000000000000, 0x0,                // 1
        0xc800000000000000, 0x0,                // 2
        0xfa00000000000000, 0x0,                // 3
        0x9c40000000000000, 0x0,                // 4
        0xc350000000000000, 0x0,                // 5
        0xf424000000000000, 0x0,                // 6
        0x9896800000000000, 0x0,                // 7
        0xbebc200000000000, 0x0,                // 8
        0xee6b280000000000, 0x0,                // 9
        0x9502f90000000000, 0x0,                // 10
        0xba43b74000000000, 0x0,                // 11
        0xe8d4a51000000000, 0x0,                // 12
        0x9184e72a00000000, 0x0,                // 13
        0xb5e620f480000000, 0x0,                // 14
        0xe35fa931a0000000, 0x0,                // 15
        0x8e1bc9bf04000000, 0x0,                // 16
        0xb1a2bc2ec5000000, 0x0,                // 17
        0xde0b6b3a76400000, 0x0,                // 18
        0x8ac7230489e80000, 0x0,                // 19
        0xad78ebc5ac620000, 0x0,                // 20
        0xd8d726b7177a8000, 0x0,                // 21
        0x878678326eac9000, 0x0,                // 22
        0xa968163f0a57b400, 0x0,                // 23
        0xd3c21bcecceda100, 0x0,                // 24
        0x84595161401484a0, 0x0,                // 25
        0xa56fa5b99019a5c8, 0x0,                // 26
        0xcecb8f27f4200f3a, 0x0,                // 27
        0x813f3978f8940984, 0x4000000000000000, // 28
        0xa18f07d736b90be5, 0x5000000000000000, // 29
        0xc9f2c9cd04674ede, 0xa400000000000000, // 30
        0xfc6f7c4045812296, 0x4d00000000000000, // 31
        0x9dc5ada82b70b59d, 0xf020000000000000, // 32
        0xc5371912364ce305, 0x6c28000000000000, // 33
        0xf684df56c3e01bc6, 0xc732000000000000, // 34
        0x9a130b963a6c115c, 0x3c7f400000000000, // 35
        0xc097ce7bc90715b3, 0x4b9f100000000000, // 36
        0xf0bdc21abb48db20, 0x1e86d40000000000, // 37
        0x96769950b50d88f4, 0x1314448000000000, // 38
        0xbc143fa4e250eb31, 0x17d955a000000000, // 39
        0xeb194f8e1ae525fd, 0x5dcfab0800000000, // 40
        0x92efd1b8d0cf37be, 0x5aa1cae500000000, // 41
        0xb7abc627050305ad, 0xf14a3d9e40000000, // 42
        0xe596b7b0c643c719, 0x6d9ccd05d0000000, // 43
        0x8f7e32ce7bea5c6f, 0xe4820023a2000000, // 44
        0xb35dbf821ae4f38b, 0xdda2802c8a800000, // 45
        0xe0352f62a19e306e, 0xd50b2037ad200000, // 46
        0x8c213d9da502de45, 0x4526f422cc340000, // 47
#ifdef __amd64__
        if (regular) [[likely]] // branch
            k = (q * 315653) >> 20;
        else
            k = (q * 315653 - 131237) >> 20;
#else
        // use this branchless code for apple M1, better performance
        // when ieee_exponent == 1 or 0 ; k=-324
        // so we can use (ieee_exponent - 1075) to replace q
        k = ((ieee_exponent - 1075) * 315653 - (regular ? 0 : 131237 ))>>20;
#endif
        int h = q + (((-1 - k) * 217707) >> 16);
        u64 *p10 = (u64 *)&pow10_ptr[(-1 - k) * 2];
        u128 cb = c << (h + 1 + offset);
        u128 hi128 = (cb * p10[0] + ((cb * p10[1]) >> 64)); // p10[0] : high 64bit ; p10[1] : low 64bit
        u64 dot_one = hi128 >> offset;   // == floor(2**64*n)    ; slow instruction
        u64 half_ulp = (p10[0] >> (-h)) + ((c + 1) & 1) ;   // -h ---> range [1,4]  ; 2**(q-1) * 10^(-k-1)
        u64 ten = (hi128 >> (offset + 64) ) * 10; // == 10*m
        //u64 one = ((dot_one * (u128)10) >> 64)  + ( (u64)(dot_one * (u128)10) >= 0x7ffffffffffffffaull) - (dot_one == (u64)1 << 62) ;
        //u64 one = ((dot_one * (u128)10 + (1ull<<63) + 6) >> 64) - (dot_one == (u64)1 << 62) ;
#ifdef __amd64__
        // (dot_one == (1ull << 62)) equal to (n==0.25)
        u64 offset_num = (dot_one == (1ull << 62)) ? 0 : (1ull<<63) + 6 ;
        u64 one = (dot_one * (u128)10 + offset_num ) >> 64 ;
        if(regular) [[likely]]
        {
            one = (half_ulp > dot_one) ? 0 : one;
        }
        else
        {
            // 10n - floor(10n) > 2**(q-2) * 10^(-k-1) * 10
            if (((((dot_one >> 4) * 10) << 4) >> 4) > (((half_ulp >> 4) * 5)))
                one = (((dot_one >> 4) * 10) >> 60) + 1;
            // if ( (((dot_one >> 4) * 5) & ( (1ull << 59 ) - 1)) > (((half_ulp >> 5) * 5)))
            //     one = (((dot_one >> 4) * 5) >> 59) + 1;
            one = ((half_ulp >> 1) > dot_one) ? 0 : one;
        }
        one = (half_ulp  > ~0 - dot_one) ? 10 : one;
        //printf("not comp half_ulp = %llx,max-dot_one = %llx\n",half_ulp, ~0 - dot_one);
        //one = (half_ulp + dot_one < half_ulp ) ? 10 : one;
#else
        // u64 offset_num = ((bitarray_irregular[exp/64]>>(exp%64)) & irregular) ? ~0 : (1ull<<63) + 6 ;
        // u64 offset_num = (((bitarray_irregular[exp/64]>>(exp%64)) & irregular)<<62) + (1ull<<63) + 6 ;
        // offset_num = (dot_one == (1ull << 62)) ? 0 : offset_num ;
        // u64 one = (dot_one * (u128)10 + offset_num ) >> 64 ;

        u64 one = ((dot_one * (u128)10) >> 64)  + ( (u64)(dot_one * (u128)10) > ((dot_one == (1ull << 62)) ? ~0 : 0x7ffffffffffffff9ull) ) ;
        if(regular)[[likely]] {
            one = (half_ulp > dot_one) ? 0 : one;
        }else{
            one = ((half_ulp >> 1) > dot_one) ? 0 : one;
            one += (bitarray_irregular[exp/64]>>(exp%64)) & 1;
        }
        one = (half_ulp  > ~0 - dot_one) ? 10 : one;
        //one = (half_ulp + dot_one < half_ulp ) ? 10 : one;
#endif
        *dec = ten + one;
        *e10 = k;
    }
}

# %% [markdown]
# First, convert the floating-point number $v$ to $ c * 2^q $.
# $$
# v = c * 2^q
# $$
# It can be easily determined that the range of q is from 1-1075 to 2046-1075 , equivalent to $[-1074, 971]$.
# $$
# q \in [-1074, 971]
# $$
#
# The calculation method of k is :
# $$
# k=\lfloor q\cdot \lg(2) \rfloor \,\,\text{if}\,\,v\in regular\,\,\text{else}\,\,\lfloor q\cdot \lg(2) - \lg(\frac{4}{3}) \rfloor
# $$
# c code implementation:

# %%
k = (q * 315653 - (regular ? 0 : 131237 )) >> 20;
//k = (q * 315653 - (irregular ? 131237 : 0 )) >> 20;

# %% [markdown]
# python proof code.

# %%
import math
for q in range(-1074,972):
    k_regular = math.floor(q*math.log10(2))
    k_irregular = math.floor(q*math.log10(2) - math.log10(4/3))
    k_regular_opt = (q * 315653) >> 20
    k_irregular_opt = (q * 315653 - 131237) >> 20
    if(k_regular!= k_regular_opt or k_irregular!= k_irregular_opt):
        print("error:",q, k_regular, k_irregular, k_regular_opt, k_irregular_opt)
        exit()
print("Ok")
# Out:
# Ok

# %% [markdown]
# To reduce instruction dependency, the calculation method of k can be equivalent to the following c code.

# %%
k = ((ieee_exponent - 1075) * 315653 - (irregular ? 131237 : 0 )) >> 20;

# %% [markdown]
# proof : The following four values are all -324. Therefore, when `ieee_exponent is 0`, the correct result can be calculated.

# %%
# run this code in the terminal to get the results
print( (-1074 * 315653 - 0) >> 20 )
print( (-1074 * 315653 - 131237) >> 20 )
print( (-1075 * 315653 - 0) >> 20 )
print( (-1075 * 315653 - 131237) >> 20 )
# Out:
# -324
# -324
# -324
# -324

# %% [markdown]
# We need to obtain the value of $ 10 ^ {-k-1} $ through the lookup table. Calculate the range of $ -k-1 $.

# %%
k_max = (971 * 315653) >> 20
k_min = (-1074 * 315653 - 131237) >> 20
get_e10_min = - k_max - 1
get_e10_max = - k_min - 1
print(get_e10_min, get_e10_max) # [-293,323]
# Out:
# -293 323

# %% [markdown]
# $$
# - k - 1 \in [-293,323]
# $$

# %% [markdown]
# The python code for calculating the lookup table is as follows:

# %%
import math
log2_10 = math.log2(10)
print("\ngenerate xjb64 lut:")
BIT = 128 - 1 ## 127
ans = 0 ## 39
i=0
while 1:
    if(i*log2_10>=BIT):
        ans=i
        break
    i=i+1
#print("ans = ",ans) # ans = 39
for i in range(-292-1,324,1):
    e10 = abs(i)
    e2 = abs(math.floor(i*log2_10) - BIT)
    round_up = 0
    if(i < 0):
        num = 2**e2//10**e10
        round_up = 1
    elif(i >= ans):
        num = 10**e10//2**e2
        round_up = 0 if(num * (2**e2) == 10**e10) else 1
    else:
        num = 10**e10*2**e2
    result = num + round_up
    print(hex(result >> 64),end=",")
    print(hex(result & ((2**64) - 1)),", //",i,end='\n')
# Out:
# generate xjb64 lut:
# 0xcc5fc196fefd7d0c,0x1e53ed49a96272c9 , // -293
# 0xff77b1fcbebcdc4f,0x25e8e89c13bb0f7b , // -292
# 0x9faacf3df73609b1,0x77b191618c54e9ad , // -291
# 0xc795830d75038c1d,0xd59df5b9ef6a2418 , // -290
# 0xf97ae3d0d2446f25,0x4b0573286b44ad1e , // -289
# 0x9becce62836ac577,0x4ee367f9430aec33 , // -288
# 0xc2e801fb244576d5,0x229c41f793cda740 , // -287
# 0xf3a20279ed56d48a,0x6b43527578c11110 , // -286
# 0x9845418c345644d6,0x830a13896b78aaaa , // -285
# 0xbe5691ef416bd60c,0x23cc986bc656d554 , // -284
# 0xedec366b11c6cb8f,0x2cbfbe86b7ec8aa9 , // -283
# 0x94b3a202eb1c3f39,0x7bf7d71432f3d6aa , // -282
# 0xb9e08a83a5e34f07,0xdaf5ccd93fb0cc54 , // -281
# 0xe858ad248f5c22c9,0xd1b3400f8f9cff69 , // -280
# 0x91376c36d99995be,0x23100809b9c21fa2 , // -279
# 0xb58547448ffffb2d,0xabd40a0c2832a78b , // -278
# 0xe2e69915b3fff9f9,0x16c90c8f323f516d , // -277
# 0x8dd01fad907ffc3b,0xae3da7d97f6792e4 , // -276
# 0xb1442798f49ffb4a,0x99cd11cfdf41779d , // -275
# 0xdd95317f31c7fa1d,0x40405643d711d584 , // -274
# 0x8a7d3eef7f1cfc52,0x482835ea666b2573 , // -273
# 0xad1c8eab5ee43b66,0xda3243650005eed0 , // -272
# 0xd863b256369d4a40,0x90bed43e40076a83 , // -271
# 0x873e4f75e2224e68,0x5a7744a6e804a292 , // -270
# 0xa90de3535aaae202,0x711515d0a205cb37 , // -269
# 0xd3515c2831559a83,0xd5a5b44ca873e04 , // -268
# 0x8412d9991ed58091,0xe858790afe9486c3 , // -267
# 0xa5178fff668ae0b6,0x626e974dbe39a873 , // -266
# 0xce5d73ff402d98e3,0xfb0a3d212dc81290 , // -265
# 0x80fa687f881c7f8e,0x7ce66634bc9d0b9a , // -264
# 0xa139029f6a239f72,0x1c1fffc1ebc44e81 , // -263
# 0xc987434744ac874e,0xa327ffb266b56221 , // -262
# 0xfbe9141915d7a922,0x4bf1ff9f0062baa9 , // -261
# 0x9d71ac8fada6c9b5,0x6f773fc3603db4aa , // -260
# 0xc4ce17b399107c22,0xcb550fb4384d21d4 , // -259
# 0xf6019da07f549b2b,0x7e2a53a146606a49 , // -258
# 0x99c102844f94e0fb,0x2eda7444cbfc426e , // -257
# 0xc0314325637a1939,0xfa911155fefb5309 , // -256
# 0xf03d93eebc589f88,0x793555ab7eba27cb , // -255
# 0x96267c7535b763b5,0x4bc1558b2f3458df , // -254
# 0xbbb01b9283253ca2,0x9eb1aaedfb016f17 , // -253
# 0xea9c227723ee8bcb,0x465e15a979c1cadd , // -252
# 0x92a1958a7675175f,0xbfacd89ec191eca , // -251
# 0xb749faed14125d36,0xcef980ec671f667c , // -250
# 0xe51c79a85916f484,0x82b7e12780e7401b , // -249
# 0x8f31cc0937ae58d2,0xd1b2ecb8b0908811 , // -248
# 0xb2fe3f0b8599ef07,0x861fa7e6dcb4aa16 , // -247
# 0xdfbdcece67006ac9,0x67a791e093e1d49b , // -246
# 0x8bd6a141006042bd,0xe0c8bb2c5c6d24e1 , // -245
# 0xaecc49914078536d,0x58fae9f773886e19 , // -244
# 0xda7f5bf590966848,0xaf39a475506a899f , // -243
# 0x888f99797a5e012d,0x6d8406c952429604 , // -242
# 0xaab37fd7d8f58178,0xc8e5087ba6d33b84 , // -241
# 0xd5605fcdcf32e1d6,0xfb1e4a9a90880a65 , // -240
# 0x855c3be0a17fcd26,0x5cf2eea09a550680 , // -239
# 0xa6b34ad8c9dfc06f,0xf42faa48c0ea481f , // -238
# 0xd0601d8efc57b08b,0xf13b94daf124da27 , // -237
# 0x823c12795db6ce57,0x76c53d08d6b70859 , // -236
# 0xa2cb1717b52481ed,0x54768c4b0c64ca6f , // -235
# 0xcb7ddcdda26da268,0xa9942f5dcf7dfd0a , // -234
# 0xfe5d54150b090b02,0xd3f93b35435d7c4d , // -233
# 0x9efa548d26e5a6e1,0xc47bc5014a1a6db0 , // -232
# 0xc6b8e9b0709f109a,0x359ab6419ca1091c , // -231
# 0xf867241c8cc6d4c0,0xc30163d203c94b63 , // -230
# 0x9b407691d7fc44f8,0x79e0de63425dcf1e , // -229
# 0xc21094364dfb5636,0x985915fc12f542e5 , // -228
# 0xf294b943e17a2bc4,0x3e6f5b7b17b2939e , // -227
# 0x979cf3ca6cec5b5a,0xa705992ceecf9c43 , // -226
# 0xbd8430bd08277231,0x50c6ff782a838354 , // -225
# 0xece53cec4a314ebd,0xa4f8bf5635246429 , // -224
# 0x940f4613ae5ed136,0x871b7795e136be9a , // -223
# 0xb913179899f68584,0x28e2557b59846e40 , // -222
# 0xe757dd7ec07426e5,0x331aeada2fe589d0 , // -221
# 0x9096ea6f3848984f,0x3ff0d2c85def7622 , // -220
# 0xb4bca50b065abe63,0xfed077a756b53aa , // -219
# 0xe1ebce4dc7f16dfb,0xd3e8495912c62895 , // -218
# 0x8d3360f09cf6e4bd,0x64712dd7abbbd95d , // -217
# 0xb080392cc4349dec,0xbd8d794d96aacfb4 , // -216
# 0xdca04777f541c567,0xecf0d7a0fc5583a1 , // -215
# 0x89e42caaf9491b60,0xf41686c49db57245 , // -214
# 0xac5d37d5b79b6239,0x311c2875c522ced6 , // -213
# 0xd77485cb25823ac7,0x7d633293366b828c , // -212
# 0x86a8d39ef77164bc,0xae5dff9c02033198 , // -211
# 0xa8530886b54dbdeb,0xd9f57f830283fdfd , // -210
# 0xd267caa862a12d66,0xd072df63c324fd7c , // -209
# 0x8380dea93da4bc60,0x4247cb9e59f71e6e , // -208
# 0xa46116538d0deb78,0x52d9be85f074e609 , // -207
# 0xcd795be870516656,0x67902e276c921f8c , // -206
# 0x806bd9714632dff6,0xba1cd8a3db53b7 , // -205
# 0xa086cfcd97bf97f3,0x80e8a40eccd228a5 , // -204
# 0xc8a883c0fdaf7df0,0x6122cd128006b2ce , // -203
# 0xfad2a4b13d1b5d6c,0x796b805720085f82 , // -202
# 0x9cc3a6eec6311a63,0xcbe3303674053bb1 , // -201
# 0xc3f490aa77bd60fc,0xbedbfc4411068a9d , // -200
# 0xf4f1b4d515acb93b,0xee92fb5515482d45 , // -199
# 0x991711052d8bf3c5,0x751bdd152d4d1c4b , // -198
# 0xbf5cd54678eef0b6,0xd262d45a78a0635e , // -197
# 0xef340a98172aace4,0x86fb897116c87c35 , // -196
# 0x9580869f0e7aac0e,0xd45d35e6ae3d4da1 , // -195
# 0xbae0a846d2195712,0x8974836059cca10a , // -194
# 0xe998d258869facd7,0x2bd1a438703fc94c , // -193
# 0x91ff83775423cc06,0x7b6306a34627ddd0 , // -192
# 0xb67f6455292cbf08,0x1a3bc84c17b1d543 , // -191
# 0xe41f3d6a7377eeca,0x20caba5f1d9e4a94 , // -190
# 0x8e938662882af53e,0x547eb47b7282ee9d , // -189
# 0xb23867fb2a35b28d,0xe99e619a4f23aa44 , // -188
# 0xdec681f9f4c31f31,0x6405fa00e2ec94d5 , // -187
# 0x8b3c113c38f9f37e,0xde83bc408dd3dd05 , // -186
# 0xae0b158b4738705e,0x9624ab50b148d446 , // -185
# 0xd98ddaee19068c76,0x3badd624dd9b0958 , // -184
# 0x87f8a8d4cfa417c9,0xe54ca5d70a80e5d7 , // -183
# 0xa9f6d30a038d1dbc,0x5e9fcf4ccd211f4d , // -182
# 0xd47487cc8470652b,0x7647c32000696720 , // -181
# 0x84c8d4dfd2c63f3b,0x29ecd9f40041e074 , // -180
# 0xa5fb0a17c777cf09,0xf468107100525891 , // -179
# 0xcf79cc9db955c2cc,0x7182148d4066eeb5 , // -178
# 0x81ac1fe293d599bf,0xc6f14cd848405531 , // -177
# 0xa21727db38cb002f,0xb8ada00e5a506a7d , // -176
# 0xca9cf1d206fdc03b,0xa6d90811f0e4851d , // -175
# 0xfd442e4688bd304a,0x908f4a166d1da664 , // -174
# 0x9e4a9cec15763e2e,0x9a598e4e043287ff , // -173
# 0xc5dd44271ad3cdba,0x40eff1e1853f29fe , // -172
# 0xf7549530e188c128,0xd12bee59e68ef47d , // -171
# 0x9a94dd3e8cf578b9,0x82bb74f8301958cf , // -170
# 0xc13a148e3032d6e7,0xe36a52363c1faf02 , // -169
# 0xf18899b1bc3f8ca1,0xdc44e6c3cb279ac2 , // -168
# 0x96f5600f15a7b7e5,0x29ab103a5ef8c0ba , // -167
# 0xbcb2b812db11a5de,0x7415d448f6b6f0e8 , // -166
# 0xebdf661791d60f56,0x111b495b3464ad22 , // -165
# 0x936b9fcebb25c995,0xcab10dd900beec35 , // -164
# 0xb84687c269ef3bfb,0x3d5d514f40eea743 , // -163
# 0xe65829b3046b0afa,0xcb4a5a3112a5113 , // -162
# 0x8ff71a0fe2c2e6dc,0x47f0e785eaba72ac , // -161
# 0xb3f4e093db73a093,0x59ed216765690f57 , // -160
# 0xe0f218b8d25088b8,0x306869c13ec3532d , // -159
# 0x8c974f7383725573,0x1e414218c73a13fc , // -158
# 0xafbd2350644eeacf,0xe5d1929ef90898fb , // -157
# 0xdbac6c247d62a583,0xdf45f746b74abf3a , // -156
# 0x894bc396ce5da772,0x6b8bba8c328eb784 , // -155
# 0xab9eb47c81f5114f,0x66ea92f3f326565 , // -154
# 0xd686619ba27255a2,0xc80a537b0efefebe , // -153
# 0x8613fd0145877585,0xbd06742ce95f5f37 , // -152
# 0xa798fc4196e952e7,0x2c48113823b73705 , // -151
# 0xd17f3b51fca3a7a0,0xf75a15862ca504c6 , // -150
# 0x82ef85133de648c4,0x9a984d73dbe722fc , // -149
# 0xa3ab66580d5fdaf5,0xc13e60d0d2e0ebbb , // -148
# 0xcc963fee10b7d1b3,0x318df905079926a9 , // -147
# 0xffbbcfe994e5c61f,0xfdf17746497f7053 , // -146
# 0x9fd561f1fd0f9bd3,0xfeb6ea8bedefa634 , // -145
# 0xc7caba6e7c5382c8,0xfe64a52ee96b8fc1 , // -144
# 0xf9bd690a1b68637b,0x3dfdce7aa3c673b1 , // -143
# 0x9c1661a651213e2d,0x6bea10ca65c084f , // -142
# 0xc31bfa0fe5698db8,0x486e494fcff30a63 , // -141
# 0xf3e2f893dec3f126,0x5a89dba3c3efccfb , // -140
# 0x986ddb5c6b3a76b7,0xf89629465a75e01d , // -139
# 0xbe89523386091465,0xf6bbb397f1135824 , // -138
# 0xee2ba6c0678b597f,0x746aa07ded582e2d , // -137
# 0x94db483840b717ef,0xa8c2a44eb4571cdd , // -136
# 0xba121a4650e4ddeb,0x92f34d62616ce414 , // -135
# 0xe896a0d7e51e1566,0x77b020baf9c81d18 , // -134
# 0x915e2486ef32cd60,0xace1474dc1d122f , // -133
# 0xb5b5ada8aaff80b8,0xd819992132456bb , // -132
# 0xe3231912d5bf60e6,0x10e1fff697ed6c6a , // -131
# 0x8df5efabc5979c8f,0xca8d3ffa1ef463c2 , // -130
# 0xb1736b96b6fd83b3,0xbd308ff8a6b17cb3 , // -129
# 0xddd0467c64bce4a0,0xac7cb3f6d05ddbdf , // -128
# 0x8aa22c0dbef60ee4,0x6bcdf07a423aa96c , // -127
# 0xad4ab7112eb3929d,0x86c16c98d2c953c7 , // -126
# 0xd89d64d57a607744,0xe871c7bf077ba8b8 , // -125
# 0x87625f056c7c4a8b,0x11471cd764ad4973 , // -124
# 0xa93af6c6c79b5d2d,0xd598e40d3dd89bd0 , // -123
# 0xd389b47879823479,0x4aff1d108d4ec2c4 , // -122
# 0x843610cb4bf160cb,0xcedf722a585139bb , // -121
# 0xa54394fe1eedb8fe,0xc2974eb4ee658829 , // -120
# 0xce947a3da6a9273e,0x733d226229feea33 , // -119
# 0x811ccc668829b887,0x806357d5a3f5260 , // -118
# 0xa163ff802a3426a8,0xca07c2dcb0cf26f8 , // -117
# 0xc9bcff6034c13052,0xfc89b393dd02f0b6 , // -116
# 0xfc2c3f3841f17c67,0xbbac2078d443ace3 , // -115
# 0x9d9ba7832936edc0,0xd54b944b84aa4c0e , // -114
# 0xc5029163f384a931,0xa9e795e65d4df12 , // -113
# 0xf64335bcf065d37d,0x4d4617b5ff4a16d6 , // -112
# 0x99ea0196163fa42e,0x504bced1bf8e4e46 , // -111
# 0xc06481fb9bcf8d39,0xe45ec2862f71e1d7 , // -110
# 0xf07da27a82c37088,0x5d767327bb4e5a4d , // -109
# 0x964e858c91ba2655,0x3a6a07f8d510f870 , // -108
# 0xbbe226efb628afea,0x890489f70a55368c , // -107
# 0xeadab0aba3b2dbe5,0x2b45ac74ccea842f , // -106
# 0x92c8ae6b464fc96f,0x3b0b8bc90012929e , // -105
# 0xb77ada0617e3bbcb,0x9ce6ebb40173745 , // -104
# 0xe55990879ddcaabd,0xcc420a6a101d0516 , // -103
# 0x8f57fa54c2a9eab6,0x9fa946824a12232e , // -102
# 0xb32df8e9f3546564,0x47939822dc96abfa , // -101
# 0xdff9772470297ebd,0x59787e2b93bc56f8 , // -100
# 0x8bfbea76c619ef36,0x57eb4edb3c55b65b , // -99
# 0xaefae51477a06b03,0xede622920b6b23f2 , // -98
# 0xdab99e59958885c4,0xe95fab368e45ecee , // -97
# 0x88b402f7fd75539b,0x11dbcb0218ebb415 , // -96
# 0xaae103b5fcd2a881,0xd652bdc29f26a11a , // -95
# 0xd59944a37c0752a2,0x4be76d3346f04960 , // -94
# 0x857fcae62d8493a5,0x6f70a4400c562ddc , // -93
# 0xa6dfbd9fb8e5b88e,0xcb4ccd500f6bb953 , // -92
# 0xd097ad07a71f26b2,0x7e2000a41346a7a8 , // -91
# 0x825ecc24c873782f,0x8ed400668c0c28c9 , // -90
# 0xa2f67f2dfa90563b,0x728900802f0f32fb , // -89
# 0xcbb41ef979346bca,0x4f2b40a03ad2ffba , // -88
# 0xfea126b7d78186bc,0xe2f610c84987bfa9 , // -87
# 0x9f24b832e6b0f436,0xdd9ca7d2df4d7ca , // -86
# 0xc6ede63fa05d3143,0x91503d1c79720dbc , // -85
# 0xf8a95fcf88747d94,0x75a44c6397ce912b , // -84
# 0x9b69dbe1b548ce7c,0xc986afbe3ee11abb , // -83
# 0xc24452da229b021b,0xfbe85badce996169 , // -82
# 0xf2d56790ab41c2a2,0xfae27299423fb9c4 , // -81
# 0x97c560ba6b0919a5,0xdccd879fc967d41b , // -80
# 0xbdb6b8e905cb600f,0x5400e987bbc1c921 , // -79
# 0xed246723473e3813,0x290123e9aab23b69 , // -78
# 0x9436c0760c86e30b,0xf9a0b6720aaf6522 , // -77
# 0xb94470938fa89bce,0xf808e40e8d5b3e6a , // -76
# 0xe7958cb87392c2c2,0xb60b1d1230b20e05 , // -75
# 0x90bd77f3483bb9b9,0xb1c6f22b5e6f48c3 , // -74
# 0xb4ecd5f01a4aa828,0x1e38aeb6360b1af4 , // -73
# 0xe2280b6c20dd5232,0x25c6da63c38de1b1 , // -72
# 0x8d590723948a535f,0x579c487e5a38ad0f , // -71
# 0xb0af48ec79ace837,0x2d835a9df0c6d852 , // -70
# 0xdcdb1b2798182244,0xf8e431456cf88e66 , // -69
# 0x8a08f0f8bf0f156b,0x1b8e9ecb641b5900 , // -68
# 0xac8b2d36eed2dac5,0xe272467e3d222f40 , // -67
# 0xd7adf884aa879177,0x5b0ed81dcc6abb10 , // -66
# 0x86ccbb52ea94baea,0x98e947129fc2b4ea , // -65
# 0xa87fea27a539e9a5,0x3f2398d747b36225 , // -64
# 0xd29fe4b18e88640e,0x8eec7f0d19a03aae , // -63
# 0x83a3eeeef9153e89,0x1953cf68300424ad , // -62
# 0xa48ceaaab75a8e2b,0x5fa8c3423c052dd8 , // -61
# 0xcdb02555653131b6,0x3792f412cb06794e , // -60
# 0x808e17555f3ebf11,0xe2bbd88bbee40bd1 , // -59
# 0xa0b19d2ab70e6ed6,0x5b6aceaeae9d0ec5 , // -58
# 0xc8de047564d20a8b,0xf245825a5a445276 , // -57
# 0xfb158592be068d2e,0xeed6e2f0f0d56713 , // -56
# 0x9ced737bb6c4183d,0x55464dd69685606c , // -55
# 0xc428d05aa4751e4c,0xaa97e14c3c26b887 , // -54
# 0xf53304714d9265df,0xd53dd99f4b3066a9 , // -53
# 0x993fe2c6d07b7fab,0xe546a8038efe402a , // -52
# 0xbf8fdb78849a5f96,0xde98520472bdd034 , // -51
# 0xef73d256a5c0f77c,0x963e66858f6d4441 , // -50
# 0x95a8637627989aad,0xdde7001379a44aa9 , // -49
# 0xbb127c53b17ec159,0x5560c018580d5d53 , // -48
# 0xe9d71b689dde71af,0xaab8f01e6e10b4a7 , // -47
# 0x9226712162ab070d,0xcab3961304ca70e9 , // -46
# 0xb6b00d69bb55c8d1,0x3d607b97c5fd0d23 , // -45
# 0xe45c10c42a2b3b05,0x8cb89a7db77c506b , // -44
# 0x8eb98a7a9a5b04e3,0x77f3608e92adb243 , // -43
# 0xb267ed1940f1c61c,0x55f038b237591ed4 , // -42
# 0xdf01e85f912e37a3,0x6b6c46dec52f6689 , // -41
# 0x8b61313bbabce2c6,0x2323ac4b3b3da016 , // -40
# 0xae397d8aa96c1b77,0xabec975e0a0d081b , // -39
# 0xd9c7dced53c72255,0x96e7bd358c904a22 , // -38
# 0x881cea14545c7575,0x7e50d64177da2e55 , // -37
# 0xaa242499697392d2,0xdde50bd1d5d0b9ea , // -36
# 0xd4ad2dbfc3d07787,0x955e4ec64b44e865 , // -35
# 0x84ec3c97da624ab4,0xbd5af13bef0b113f , // -34
# 0xa6274bbdd0fadd61,0xecb1ad8aeacdd58f , // -33
# 0xcfb11ead453994ba,0x67de18eda5814af3 , // -32
# 0x81ceb32c4b43fcf4,0x80eacf948770ced8 , // -31
# 0xa2425ff75e14fc31,0xa1258379a94d028e , // -30
# 0xcad2f7f5359a3b3e,0x96ee45813a04331 , // -29
# 0xfd87b5f28300ca0d,0x8bca9d6e188853fd , // -28
# 0x9e74d1b791e07e48,0x775ea264cf55347e , // -27
# 0xc612062576589dda,0x95364afe032a819e , // -26
# 0xf79687aed3eec551,0x3a83ddbd83f52205 , // -25
# 0x9abe14cd44753b52,0xc4926a9672793543 , // -24
# 0xc16d9a0095928a27,0x75b7053c0f178294 , // -23
# 0xf1c90080baf72cb1,0x5324c68b12dd6339 , // -22
# 0x971da05074da7bee,0xd3f6fc16ebca5e04 , // -21
# 0xbce5086492111aea,0x88f4bb1ca6bcf585 , // -20
# 0xec1e4a7db69561a5,0x2b31e9e3d06c32e6 , // -19
# 0x9392ee8e921d5d07,0x3aff322e62439fd0 , // -18
# 0xb877aa3236a4b449,0x9befeb9fad487c3 , // -17
# 0xe69594bec44de15b,0x4c2ebe687989a9b4 , // -16
# 0x901d7cf73ab0acd9,0xf9d37014bf60a11 , // -15
# 0xb424dc35095cd80f,0x538484c19ef38c95 , // -14
# 0xe12e13424bb40e13,0x2865a5f206b06fba , // -13
# 0x8cbccc096f5088cb,0xf93f87b7442e45d4 , // -12
# 0xafebff0bcb24aafe,0xf78f69a51539d749 , // -11
# 0xdbe6fecebdedd5be,0xb573440e5a884d1c , // -10
# 0x89705f4136b4a597,0x31680a88f8953031 , // -9
# 0xabcc77118461cefc,0xfdc20d2b36ba7c3e , // -8
# 0xd6bf94d5e57a42bc,0x3d32907604691b4d , // -7
# 0x8637bd05af6c69b5,0xa63f9a49c2c1b110 , // -6
# 0xa7c5ac471b478423,0xfcf80dc33721d54 , // -5
# 0xd1b71758e219652b,0xd3c36113404ea4a9 , // -4
# 0x83126e978d4fdf3b,0x645a1cac083126ea , // -3
# 0xa3d70a3d70a3d70a,0x3d70a3d70a3d70a4 , // -2
# 0xcccccccccccccccc,0xcccccccccccccccd , // -1
# 0x8000000000000000,0x0 , // 0
# 0xa000000000000000,0x0 , // 1
# 0xc800000000000000,0x0 , // 2
# 0xfa00000000000000,0x0 , // 3
# 0x9c40000000000000,0x0 , // 4
# 0xc350000000000000,0x0 , // 5
# 0xf424000000000000,0x0 , // 6
# 0x9896800000000000,0x0 , // 7
# 0xbebc200000000000,0x0 , // 8
# 0xee6b280000000000,0x0 , // 9
# 0x9502f90000000000,0x0 , // 10
# 0xba43b74000000000,0x0 , // 11
# 0xe8d4a51000000000,0x0 , // 12
# 0x9184e72a00000000,0x0 , // 13
# 0xb5e620f480000000,0x0 , // 14
# 0xe35fa931a0000000,0x0 , // 15
# 0x8e1bc9bf04000000,0x0 , // 16
# 0xb1a2bc2ec5000000,0x0 , // 17
# 0xde0b6b3a76400000,0x0 , // 18
# 0x8ac7230489e80000,0x0 , // 19
# 0xad78ebc5ac620000,0x0 , // 20
# 0xd8d726b7177a8000,0x0 , // 21
# 0x878678326eac9000,0x0 , // 22
# 0xa968163f0a57b400,0x0 , // 23
# 0xd3c21bcecceda100,0x0 , // 24
# 0x84595161401484a0,0x0 , // 25
# 0xa56fa5b99019a5c8,0x0 , // 26
# 0xcecb8f27f4200f3a,0x0 , // 27
# 0x813f3978f8940984,0x4000000000000000 , // 28
# 0xa18f07d736b90be5,0x5000000000000000 , // 29
# 0xc9f2c9cd04674ede,0xa400000000000000 , // 30
# 0xfc6f7c4045812296,0x4d00000000000000 , // 31
# 0x9dc5ada82b70b59d,0xf020000000000000 , // 32
# 0xc5371912364ce305,0x6c28000000000000 , // 33
# 0xf684df56c3e01bc6,0xc732000000000000 , // 34
# 0x9a130b963a6c115c,0x3c7f400000000000 , // 35
# 0xc097ce7bc90715b3,0x4b9f100000000000 , // 36
# 0xf0bdc21abb48db20,0x1e86d40000000000 , // 37
# 0x96769950b50d88f4,0x1314448000000000 , // 38
# 0xbc143fa4e250eb31,0x17d955a000000000 , // 39
# 0xeb194f8e1ae525fd,0x5dcfab0800000000 , // 40
# 0x92efd1b8d0cf37be,0x5aa1cae500000000 , // 41
# 0xb7abc627050305ad,0xf14a3d9e40000000 , // 42
# 0xe596b7b0c643c719,0x6d9ccd05d0000000 , // 43
# 0x8f7e32ce7bea5c6f,0xe4820023a2000000 , // 44
# 0xb35dbf821ae4f38b,0xdda2802c8a800000 , // 45
# 0xe0352f62a19e306e,0xd50b2037ad200000 , // 46
# 0x8c213d9da502de45,0x4526f422cc340000 , // 47
# 0xaf298d050e4395d6,0x9670b12b7f410000 , // 48
# 0xdaf3f04651d47b4c,0x3c0cdd765f114000 , // 49
# 0x88d8762bf324cd0f,0xa5880a69fb6ac800 , // 50
# 0xab0e93b6efee0053,0x8eea0d047a457a00 , // 51
# 0xd5d238a4abe98068,0x72a4904598d6d880 , // 52
# 0x85a36366eb71f041,0x47a6da2b7f864750 , // 53
# 0xa70c3c40a64e6c51,0x999090b65f67d924 , // 54
# 0xd0cf4b50cfe20765,0xfff4b4e3f741cf6d , // 55
# 0x82818f1281ed449f,0xbff8f10e7a8921a5 , // 56
# 0xa321f2d7226895c7,0xaff72d52192b6a0e , // 57
# 0xcbea6f8ceb02bb39,0x9bf4f8a69f764491 , // 58
# 0xfee50b7025c36a08,0x2f236d04753d5b5 , // 59
# 0x9f4f2726179a2245,0x1d762422c946591 , // 60
# 0xc722f0ef9d80aad6,0x424d3ad2b7b97ef6 , // 61
# 0xf8ebad2b84e0d58b,0xd2e0898765a7deb3 , // 62
# 0x9b934c3b330c8577,0x63cc55f49f88eb30 , // 63
# 0xc2781f49ffcfa6d5,0x3cbf6b71c76b25fc , // 64
# 0xf316271c7fc3908a,0x8bef464e3945ef7b , // 65
# 0x97edd871cfda3a56,0x97758bf0e3cbb5ad , // 66
# 0xbde94e8e43d0c8ec,0x3d52eeed1cbea318 , // 67
# 0xed63a231d4c4fb27,0x4ca7aaa863ee4bde , // 68
# 0x945e455f24fb1cf8,0x8fe8caa93e74ef6b , // 69
# 0xb975d6b6ee39e436,0xb3e2fd538e122b45 , // 70
# 0xe7d34c64a9c85d44,0x60dbbca87196b617 , // 71
# 0x90e40fbeea1d3a4a,0xbc8955e946fe31ce , // 72
# 0xb51d13aea4a488dd,0x6babab6398bdbe42 , // 73
# 0xe264589a4dcdab14,0xc696963c7eed2dd2 , // 74
# 0x8d7eb76070a08aec,0xfc1e1de5cf543ca3 , // 75
# 0xb0de65388cc8ada8,0x3b25a55f43294bcc , // 76
# 0xdd15fe86affad912,0x49ef0eb713f39ebf , // 77
# 0x8a2dbf142dfcc7ab,0x6e3569326c784338 , // 78
# 0xacb92ed9397bf996,0x49c2c37f07965405 , // 79
# 0xd7e77a8f87daf7fb,0xdc33745ec97be907 , // 80
# 0x86f0ac99b4e8dafd,0x69a028bb3ded71a4 , // 81
# 0xa8acd7c0222311bc,0xc40832ea0d68ce0d , // 82
# 0xd2d80db02aabd62b,0xf50a3fa490c30191 , // 83
# 0x83c7088e1aab65db,0x792667c6da79e0fb , // 84
# 0xa4b8cab1a1563f52,0x577001b891185939 , // 85
# 0xcde6fd5e09abcf26,0xed4c0226b55e6f87 , // 86
# 0x80b05e5ac60b6178,0x544f8158315b05b5 , // 87
# 0xa0dc75f1778e39d6,0x696361ae3db1c722 , // 88
# 0xc913936dd571c84c,0x3bc3a19cd1e38ea , // 89
# 0xfb5878494ace3a5f,0x4ab48a04065c724 , // 90
# 0x9d174b2dcec0e47b,0x62eb0d64283f9c77 , // 91
# 0xc45d1df942711d9a,0x3ba5d0bd324f8395 , // 92
# 0xf5746577930d6500,0xca8f44ec7ee3647a , // 93
# 0x9968bf6abbe85f20,0x7e998b13cf4e1ecc , // 94
# 0xbfc2ef456ae276e8,0x9e3fedd8c321a67f , // 95
# 0xefb3ab16c59b14a2,0xc5cfe94ef3ea101f , // 96
# 0x95d04aee3b80ece5,0xbba1f1d158724a13 , // 97
# 0xbb445da9ca61281f,0x2a8a6e45ae8edc98 , // 98
# 0xea1575143cf97226,0xf52d09d71a3293be , // 99
# 0x924d692ca61be758,0x593c2626705f9c57 , // 100
# 0xb6e0c377cfa2e12e,0x6f8b2fb00c77836d , // 101
# 0xe498f455c38b997a,0xb6dfb9c0f956448 , // 102
# 0x8edf98b59a373fec,0x4724bd4189bd5ead , // 103
# 0xb2977ee300c50fe7,0x58edec91ec2cb658 , // 104
# 0xdf3d5e9bc0f653e1,0x2f2967b66737e3ee , // 105
# 0x8b865b215899f46c,0xbd79e0d20082ee75 , // 106
# 0xae67f1e9aec07187,0xecd8590680a3aa12 , // 107
# 0xda01ee641a708de9,0xe80e6f4820cc9496 , // 108
# 0x884134fe908658b2,0x3109058d147fdcde , // 109
# 0xaa51823e34a7eede,0xbd4b46f0599fd416 , // 110
# 0xd4e5e2cdc1d1ea96,0x6c9e18ac7007c91b , // 111
# 0x850fadc09923329e,0x3e2cf6bc604ddb1 , // 112
# 0xa6539930bf6bff45,0x84db8346b786151d , // 113
# 0xcfe87f7cef46ff16,0xe612641865679a64 , // 114
# 0x81f14fae158c5f6e,0x4fcb7e8f3f60c07f , // 115
# 0xa26da3999aef7749,0xe3be5e330f38f09e , // 116
# 0xcb090c8001ab551c,0x5cadf5bfd3072cc6 , // 117
# 0xfdcb4fa002162a63,0x73d9732fc7c8f7f7 , // 118
# 0x9e9f11c4014dda7e,0x2867e7fddcdd9afb , // 119
# 0xc646d63501a1511d,0xb281e1fd541501b9 , // 120
# 0xf7d88bc24209a565,0x1f225a7ca91a4227 , // 121
# 0x9ae757596946075f,0x3375788de9b06959 , // 122
# 0xc1a12d2fc3978937,0x52d6b1641c83af , // 123
# 0xf209787bb47d6b84,0xc0678c5dbd23a49b , // 124
# 0x9745eb4d50ce6332,0xf840b7ba963646e1 , // 125
# 0xbd176620a501fbff,0xb650e5a93bc3d899 , // 126
# 0xec5d3fa8ce427aff,0xa3e51f138ab4cebf , // 127
# 0x93ba47c980e98cdf,0xc66f336c36b10138 , // 128
# 0xb8a8d9bbe123f017,0xb80b0047445d4185 , // 129
# 0xe6d3102ad96cec1d,0xa60dc059157491e6 , // 130
# 0x9043ea1ac7e41392,0x87c89837ad68db30 , // 131
# 0xb454e4a179dd1877,0x29babe4598c311fc , // 132
# 0xe16a1dc9d8545e94,0xf4296dd6fef3d67b , // 133
# 0x8ce2529e2734bb1d,0x1899e4a65f58660d , // 134
# 0xb01ae745b101e9e4,0x5ec05dcff72e7f90 , // 135
# 0xdc21a1171d42645d,0x76707543f4fa1f74 , // 136
# 0x899504ae72497eba,0x6a06494a791c53a9 , // 137
# 0xabfa45da0edbde69,0x487db9d17636893 , // 138
# 0xd6f8d7509292d603,0x45a9d2845d3c42b7 , // 139
# 0x865b86925b9bc5c2,0xb8a2392ba45a9b3 , // 140
# 0xa7f26836f282b732,0x8e6cac7768d7141f , // 141
# 0xd1ef0244af2364ff,0x3207d795430cd927 , // 142
# 0x8335616aed761f1f,0x7f44e6bd49e807b9 , // 143
# 0xa402b9c5a8d3a6e7,0x5f16206c9c6209a7 , // 144
# 0xcd036837130890a1,0x36dba887c37a8c10 , // 145
# 0x802221226be55a64,0xc2494954da2c978a , // 146
# 0xa02aa96b06deb0fd,0xf2db9baa10b7bd6d , // 147
# 0xc83553c5c8965d3d,0x6f92829494e5acc8 , // 148
# 0xfa42a8b73abbf48c,0xcb772339ba1f17fa , // 149
# 0x9c69a97284b578d7,0xff2a760414536efc , // 150
# 0xc38413cf25e2d70d,0xfef5138519684abb , // 151
# 0xf46518c2ef5b8cd1,0x7eb258665fc25d6a , // 152
# 0x98bf2f79d5993802,0xef2f773ffbd97a62 , // 153
# 0xbeeefb584aff8603,0xaafb550ffacfd8fb , // 154
# 0xeeaaba2e5dbf6784,0x95ba2a53f983cf39 , // 155
# 0x952ab45cfa97a0b2,0xdd945a747bf26184 , // 156
# 0xba756174393d88df,0x94f971119aeef9e5 , // 157
# 0xe912b9d1478ceb17,0x7a37cd5601aab85e , // 158
# 0x91abb422ccb812ee,0xac62e055c10ab33b , // 159
# 0xb616a12b7fe617aa,0x577b986b314d600a , // 160
# 0xe39c49765fdf9d94,0xed5a7e85fda0b80c , // 161
# 0x8e41ade9fbebc27d,0x14588f13be847308 , // 162
# 0xb1d219647ae6b31c,0x596eb2d8ae258fc9 , // 163
# 0xde469fbd99a05fe3,0x6fca5f8ed9aef3bc , // 164
# 0x8aec23d680043bee,0x25de7bb9480d5855 , // 165
# 0xada72ccc20054ae9,0xaf561aa79a10ae6b , // 166
# 0xd910f7ff28069da4,0x1b2ba1518094da05 , // 167
# 0x87aa9aff79042286,0x90fb44d2f05d0843 , // 168
# 0xa99541bf57452b28,0x353a1607ac744a54 , // 169
# 0xd3fa922f2d1675f2,0x42889b8997915ce9 , // 170
# 0x847c9b5d7c2e09b7,0x69956135febada12 , // 171
# 0xa59bc234db398c25,0x43fab9837e699096 , // 172
# 0xcf02b2c21207ef2e,0x94f967e45e03f4bc , // 173
# 0x8161afb94b44f57d,0x1d1be0eebac278f6 , // 174
# 0xa1ba1ba79e1632dc,0x6462d92a69731733 , // 175
# 0xca28a291859bbf93,0x7d7b8f7503cfdcff , // 176
# 0xfcb2cb35e702af78,0x5cda735244c3d43f , // 177
# 0x9defbf01b061adab,0x3a0888136afa64a8 , // 178
# 0xc56baec21c7a1916,0x88aaa1845b8fdd1 , // 179
# 0xf6c69a72a3989f5b,0x8aad549e57273d46 , // 180
# 0x9a3c2087a63f6399,0x36ac54e2f678864c , // 181
# 0xc0cb28a98fcf3c7f,0x84576a1bb416a7de , // 182
# 0xf0fdf2d3f3c30b9f,0x656d44a2a11c51d6 , // 183
# 0x969eb7c47859e743,0x9f644ae5a4b1b326 , // 184
# 0xbc4665b596706114,0x873d5d9f0dde1fef , // 185
# 0xeb57ff22fc0c7959,0xa90cb506d155a7eb , // 186
# 0x9316ff75dd87cbd8,0x9a7f12442d588f3 , // 187
# 0xb7dcbf5354e9bece,0xc11ed6d538aeb30 , // 188
# 0xe5d3ef282a242e81,0x8f1668c8a86da5fb , // 189
# 0x8fa475791a569d10,0xf96e017d694487bd , // 190
# 0xb38d92d760ec4455,0x37c981dcc395a9ad , // 191
# 0xe070f78d3927556a,0x85bbe253f47b1418 , // 192
# 0x8c469ab843b89562,0x93956d7478ccec8f , // 193
# 0xaf58416654a6babb,0x387ac8d1970027b3 , // 194
# 0xdb2e51bfe9d0696a,0x6997b05fcc0319f , // 195
# 0x88fcf317f22241e2,0x441fece3bdf81f04 , // 196
# 0xab3c2fddeeaad25a,0xd527e81cad7626c4 , // 197
# 0xd60b3bd56a5586f1,0x8a71e223d8d3b075 , // 198
# 0x85c7056562757456,0xf6872d5667844e4a , // 199
# 0xa738c6bebb12d16c,0xb428f8ac016561dc , // 200
# 0xd106f86e69d785c7,0xe13336d701beba53 , // 201
# 0x82a45b450226b39c,0xecc0024661173474 , // 202
# 0xa34d721642b06084,0x27f002d7f95d0191 , // 203
# 0xcc20ce9bd35c78a5,0x31ec038df7b441f5 , // 204
# 0xff290242c83396ce,0x7e67047175a15272 , // 205
# 0x9f79a169bd203e41,0xf0062c6e984d387 , // 206
# 0xc75809c42c684dd1,0x52c07b78a3e60869 , // 207
# 0xf92e0c3537826145,0xa7709a56ccdf8a83 , // 208
# 0x9bbcc7a142b17ccb,0x88a66076400bb692 , // 209
# 0xc2abf989935ddbfe,0x6acff893d00ea436 , // 210
# 0xf356f7ebf83552fe,0x583f6b8c4124d44 , // 211
# 0x98165af37b2153de,0xc3727a337a8b704b , // 212
# 0xbe1bf1b059e9a8d6,0x744f18c0592e4c5d , // 213
# 0xeda2ee1c7064130c,0x1162def06f79df74 , // 214
# 0x9485d4d1c63e8be7,0x8addcb5645ac2ba9 , // 215
# 0xb9a74a0637ce2ee1,0x6d953e2bd7173693 , // 216
# 0xe8111c87c5c1ba99,0xc8fa8db6ccdd0438 , // 217
# 0x910ab1d4db9914a0,0x1d9c9892400a22a3 , // 218
# 0xb54d5e4a127f59c8,0x2503beb6d00cab4c , // 219
# 0xe2a0b5dc971f303a,0x2e44ae64840fd61e , // 220
# 0x8da471a9de737e24,0x5ceaecfed289e5d3 , // 221
# 0xb10d8e1456105dad,0x7425a83e872c5f48 , // 222
# 0xdd50f1996b947518,0xd12f124e28f7771a , // 223
# 0x8a5296ffe33cc92f,0x82bd6b70d99aaa70 , // 224
# 0xace73cbfdc0bfb7b,0x636cc64d1001550c , // 225
# 0xd8210befd30efa5a,0x3c47f7e05401aa4f , // 226
# 0x8714a775e3e95c78,0x65acfaec34810a72 , // 227
# 0xa8d9d1535ce3b396,0x7f1839a741a14d0e , // 228
# 0xd31045a8341ca07c,0x1ede48111209a051 , // 229
# 0x83ea2b892091e44d,0x934aed0aab460433 , // 230
# 0xa4e4b66b68b65d60,0xf81da84d56178540 , // 231
# 0xce1de40642e3f4b9,0x36251260ab9d668f , // 232
# 0x80d2ae83e9ce78f3,0xc1d72b7c6b42601a , // 233
# 0xa1075a24e4421730,0xb24cf65b8612f820 , // 234
# 0xc94930ae1d529cfc,0xdee033f26797b628 , // 235
# 0xfb9b7cd9a4a7443c,0x169840ef017da3b2 , // 236
# 0x9d412e0806e88aa5,0x8e1f289560ee864f , // 237
# 0xc491798a08a2ad4e,0xf1a6f2bab92a27e3 , // 238
# 0xf5b5d7ec8acb58a2,0xae10af696774b1dc , // 239
# 0x9991a6f3d6bf1765,0xacca6da1e0a8ef2a , // 240
# 0xbff610b0cc6edd3f,0x17fd090a58d32af4 , // 241
# 0xeff394dcff8a948e,0xddfc4b4cef07f5b1 , // 242
# 0x95f83d0a1fb69cd9,0x4abdaf101564f98f , // 243
# 0xbb764c4ca7a4440f,0x9d6d1ad41abe37f2 , // 244
# 0xea53df5fd18d5513,0x84c86189216dc5ee , // 245
# 0x92746b9be2f8552c,0x32fd3cf5b4e49bb5 , // 246
# 0xb7118682dbb66a77,0x3fbc8c33221dc2a2 , // 247
# 0xe4d5e82392a40515,0xfabaf3feaa5334b , // 248
# 0x8f05b1163ba6832d,0x29cb4d87f2a7400f , // 249
# 0xb2c71d5bca9023f8,0x743e20e9ef511013 , // 250
# 0xdf78e4b2bd342cf6,0x914da9246b255417 , // 251
# 0x8bab8eefb6409c1a,0x1ad089b6c2f7548f , // 252
# 0xae9672aba3d0c320,0xa184ac2473b529b2 , // 253
# 0xda3c0f568cc4f3e8,0xc9e5d72d90a2741f , // 254
# 0x8865899617fb1871,0x7e2fa67c7a658893 , // 255
# 0xaa7eebfb9df9de8d,0xddbb901b98feeab8 , // 256
# 0xd51ea6fa85785631,0x552a74227f3ea566 , // 257
# 0x8533285c936b35de,0xd53a88958f872760 , // 258
# 0xa67ff273b8460356,0x8a892abaf368f138 , // 259
# 0xd01fef10a657842c,0x2d2b7569b0432d86 , // 260
# 0x8213f56a67f6b29b,0x9c3b29620e29fc74 , // 261
# 0xa298f2c501f45f42,0x8349f3ba91b47b90 , // 262
# 0xcb3f2f7642717713,0x241c70a936219a74 , // 263
# 0xfe0efb53d30dd4d7,0xed238cd383aa0111 , // 264
# 0x9ec95d1463e8a506,0xf4363804324a40ab , // 265
# 0xc67bb4597ce2ce48,0xb143c6053edcd0d6 , // 266
# 0xf81aa16fdc1b81da,0xdd94b7868e94050b , // 267
# 0x9b10a4e5e9913128,0xca7cf2b4191c8327 , // 268
# 0xc1d4ce1f63f57d72,0xfd1c2f611f63a3f1 , // 269
# 0xf24a01a73cf2dccf,0xbc633b39673c8ced , // 270
# 0x976e41088617ca01,0xd5be0503e085d814 , // 271
# 0xbd49d14aa79dbc82,0x4b2d8644d8a74e19 , // 272
# 0xec9c459d51852ba2,0xddf8e7d60ed1219f , // 273
# 0x93e1ab8252f33b45,0xcabb90e5c942b504 , // 274
# 0xb8da1662e7b00a17,0x3d6a751f3b936244 , // 275
# 0xe7109bfba19c0c9d,0xcc512670a783ad5 , // 276
# 0x906a617d450187e2,0x27fb2b80668b24c6 , // 277
# 0xb484f9dc9641e9da,0xb1f9f660802dedf7 , // 278
# 0xe1a63853bbd26451,0x5e7873f8a0396974 , // 279
# 0x8d07e33455637eb2,0xdb0b487b6423e1e9 , // 280
# 0xb049dc016abc5e5f,0x91ce1a9a3d2cda63 , // 281
# 0xdc5c5301c56b75f7,0x7641a140cc7810fc , // 282
# 0x89b9b3e11b6329ba,0xa9e904c87fcb0a9e , // 283
# 0xac2820d9623bf429,0x546345fa9fbdcd45 , // 284
# 0xd732290fbacaf133,0xa97c177947ad4096 , // 285
# 0x867f59a9d4bed6c0,0x49ed8eabcccc485e , // 286
# 0xa81f301449ee8c70,0x5c68f256bfff5a75 , // 287
# 0xd226fc195c6a2f8c,0x73832eec6fff3112 , // 288
# 0x83585d8fd9c25db7,0xc831fd53c5ff7eac , // 289
# 0xa42e74f3d032f525,0xba3e7ca8b77f5e56 , // 290
# 0xcd3a1230c43fb26f,0x28ce1bd2e55f35ec , // 291
# 0x80444b5e7aa7cf85,0x7980d163cf5b81b4 , // 292
# 0xa0555e361951c366,0xd7e105bcc3326220 , // 293
# 0xc86ab5c39fa63440,0x8dd9472bf3fefaa8 , // 294
# 0xfa856334878fc150,0xb14f98f6f0feb952 , // 295
# 0x9c935e00d4b9d8d2,0x6ed1bf9a569f33d4 , // 296
# 0xc3b8358109e84f07,0xa862f80ec4700c9 , // 297
# 0xf4a642e14c6262c8,0xcd27bb612758c0fb , // 298
# 0x98e7e9cccfbd7dbd,0x8038d51cb897789d , // 299
# 0xbf21e44003acdd2c,0xe0470a63e6bd56c4 , // 300
# 0xeeea5d5004981478,0x1858ccfce06cac75 , // 301
# 0x95527a5202df0ccb,0xf37801e0c43ebc9 , // 302
# 0xbaa718e68396cffd,0xd30560258f54e6bb , // 303
# 0xe950df20247c83fd,0x47c6b82ef32a206a , // 304
# 0x91d28b7416cdd27e,0x4cdc331d57fa5442 , // 305
# 0xb6472e511c81471d,0xe0133fe4adf8e953 , // 306
# 0xe3d8f9e563a198e5,0x58180fddd97723a7 , // 307
# 0x8e679c2f5e44ff8f,0x570f09eaa7ea7649 , // 308
# 0xb201833b35d63f73,0x2cd2cc6551e513db , // 309
# 0xde81e40a034bcf4f,0xf8077f7ea65e58d2 , // 310
# 0x8b112e86420f6191,0xfb04afaf27faf783 , // 311
# 0xadd57a27d29339f6,0x79c5db9af1f9b564 , // 312
# 0xd94ad8b1c7380874,0x18375281ae7822bd , // 313
# 0x87cec76f1c830548,0x8f2293910d0b15b6 , // 314
# 0xa9c2794ae3a3c69a,0xb2eb3875504ddb23 , // 315
# 0xd433179d9c8cb841,0x5fa60692a46151ec , // 316
# 0x849feec281d7f328,0xdbc7c41ba6bcd334 , // 317
# 0xa5c7ea73224deff3,0x12b9b522906c0801 , // 318
# 0xcf39e50feae16bef,0xd768226b34870a01 , // 319
# 0x81842f29f2cce375,0xe6a1158300d46641 , // 320
# 0xa1e53af46f801c53,0x60495ae3c1097fd1 , // 321
# 0xca5e89b18b602368,0x385bb19cb14bdfc5 , // 322
# 0xfcf62c1dee382c42,0x46729e03dd9ed7b6 , // 323

# %% [markdown]
# Calculate the error range of $10^{-k-1}$ obtained through the lookup table.

# %%
import math
log2_10 = math.log2(10)
print("\ngenerate xjb64 lut:")
BIT = 128 - 1 ## 127
ans = 0 ## 39
i=0
while 1:
    if(i*log2_10>=BIT):
        ans=i
        break
    i=i+1
#print("ans = ",ans)
error_max = 0
for i in range(-292-1,325,1):
    e10 = abs(i)
    e2 = abs(math.floor(i*log2_10) - BIT)
    round_up = 0
    if(i<0):
        num = 2**e2//10**e10
        round_up = 1
    elif(i >= ans):
        num = 10**e10//2**e2
        round_up = 0 if(num * (2**e2) == 10**e10) else 1
    else:
        num = 10**e10*2**e2
    result = num + round_up
    #calc error = (result * 2**(math.floor(i*log2_10) - BIT) - 10**i) / 10**i
    #calc error = (result * 2**A - 10**B) / 10**B
    A = math.floor(i*log2_10) - BIT
    B = i
    if( A >= 0 and B >= 0):
        error = (result * 2**A - 10**B) / 10**B
    elif( A < 0 and B >= 0):
        error = (result * - 10**B * 2**(-A)) / 10**B * 2**(-A)
    else:# A<0 and B<0
        error = (result * 10**(-B) -  2**(-A)) / 2**(-A)
    print(hex(result >> 64),end=",")
    print(hex(result & ((2**64) - 1)),", //",i,end='  ')
    if round_up == 0:
        print("error = 0")
    else:
        error_max = max(error_max, error)
        print("error = ",error," = +2 **",math.log2(error))
print("error_max = ",error_max," = +2 **",math.log2(error_max))
# Out:
# generate xjb64 lut:
# 0xcc5fc196fefd7d0c,0x1e53ed49a96272c9 , // -293  error =  1.108852756624526e-39  = +2 ** -129.4061278963257
# 0xff77b1fcbebcdc4f,0x25e8e89c13bb0f7b , // -292  error =  3.726375737222397e-40  = +2 ** -130.97935064432355
# 0x9faacf3df73609b1,0x77b191618c54e9ad , // -291  error =  9.616097200440687e-40  = +2 ** -129.61167231647067
# 0xc795830d75038c1d,0xd59df5b9ef6a2418 , // -290  error =  1.9254285929142285e-41  = +2 ** -135.2538722705234
# 0xf97ae3d0d2446f25,0x4b0573286b44ad1e , // -289  error =  1.9254285929142285e-41  = +2 ** -135.2538722705234
# 0x9becce62836ac577,0x4ee367f9430aec33 , // -288  error =  1.225469241596248e-39  = +2 ** -129.2618614265643
# 0xc2e801fb244576d5,0x229c41f793cda740 , // -287  error =  2.190441206129933e-39  = +2 ** -128.42397420896071
# 0xf3a20279ed56d48a,0x6b43527578c11110 , // -286  error =  2.190441206129933e-39  = +2 ** -128.42397420896071
# 0x9845418c345644d6,0x830a13896b78aaaa , // -285  error =  2.190441206129933e-39  = +2 ** -128.42397420896071
# 0xbe5691ef416bd60c,0x23cc986bc656d554 , // -284  error =  2.141786227649466e-40  = +2 ** -131.77830930406208
# 0xedec366b11c6cb8f,0x2cbfbe86b7ec8aa9 , // -283  error =  2.141786227649466e-40  = +2 ** -131.77830930406208
# 0x94b3a202eb1c3f39,0x7bf7d71432f3d6aa , // -282  error =  2.1113907027953333e-39  = +2 ** -128.47700213337146
# 0xb9e08a83a5e34f07,0xdaf5ccd93fb0cc54 , // -281  error =  8.769781742958747e-41  = +2 ** -133.06651095218953
# 0xe858ad248f5c22c9,0xd1b3400f8f9cff69 , // -280  error =  8.769781742958747e-41  = +2 ** -133.06651095218953
# 0x91376c36d99995be,0x23100809b9c21fa2 , // -279  error =  2.0304429873807036e-39  = +2 ** -128.5334011820757
# 0xb58547448ffffb2d,0xabd40a0c2832a78b , // -278  error =  4.102704501995227e-39  = +2 ** -127.51862045299583
# 0xe2e69915b3fff9f9,0x16c90c8f323f516d , // -277  error =  1.6159906844577986e-39  = +2 ** -128.86277681905534
# 0x8dd01fad907ffc3b,0xae3da7d97f6792e4 , // -276  error =  9.528669997811511e-40  = +2 ** -129.62484893723197
# 0xb1442798f49ffb4a,0x99cd11cfdf41779d , // -275  error =  9.528669997811511e-40  = +2 ** -129.62484893723197
# 0xdd95317f31c7fa1d,0x40405643d711d584 , // -274  error =  1.040686833950422e-40  = +2 ** -132.81958780090014
# 0x8a7d3eef7f1cfc52,0x482835ea666b2573 , // -273  error =  2.820223295830591e-39  = +2 ** -128.05938630570157
# 0xad1c8eab5ee43b66,0xda3243650005eed0 , // -272  error =  3.9066851408048103e-39  = +2 ** -127.58925071437245
# 0xd863b256369d4a40,0x90bed43e40076a83 , // -271  error =  4.30007236887308e-40  = +2 ** -130.7727628553691
# 0x873e4f75e2224e68,0x5a7744a6e804a292 , // -270  error =  1.1253428176708085e-39  = +2 ** -129.38483113826456
# 0xa90de3535aaae202,0x711515d0a205cb37 , // -269  error =  3.35041667617801e-39  = +2 ** -127.81085517241767
# 0xd3515c2831559a83,0xd5a5b44ca873e04 , // -268  error =  6.803280459693682e-40  = +2 ** -130.11089323123116
# 0x8412d9991ed58091,0xe858790afe9486c3 , // -267  error =  3.528422584858586e-39  = +2 ** -127.73617234363175
# 0xa5178fff668ae0b6,0x626e974dbe39a873 , // -266  error =  1.1070913819152463e-40  = +2 ** -132.73034948503286
# 0xce5d73ff402d98e3,0xfb0a3d212dc81290 , // -265  error =  1.0220993906360744e-39  = +2 ** -129.52366020745706
# 0x80fa687f881c7f8e,0x7ce66634bc9d0b9a , // -264  error =  1.0220993906360744e-39  = +2 ** -129.52366020745706
# 0xa139029f6a239f72,0x1c1fffc1ebc44e81 , // -263  error =  3.355258436894122e-39  = +2 ** -127.80877180712771
# 0xc987434744ac874e,0xa327ffb266b56221 , // -262  error =  2.4219948183909026e-39  = +2 ** -128.27899992206943
# 0xfbe9141915d7a922,0x4bf1ff9f0062baa9 , // -261  error =  1.6753839235883275e-39  = +2 ** -128.81070396552076
# 0x9d71ac8fada6c9b5,0x6f773fc3603db4aa , // -260  error =  3.4672500711145076e-39  = +2 ** -127.76140380772195
# 0xc4ce17b399107c22,0xcb550fb4384d21d4 , // -259  error =  1.5559261804199155e-39  = +2 ** -128.91742208608537
# 0xf6019da07f549b2b,0x7e2a53a146606a49 , // -258  error =  1.5559261804199155e-39  = +2 ** -128.91742208608537
# 0x99c102844f94e0fb,0x2eda7444cbfc426e , // -257  error =  3.390797115486724e-39  = +2 ** -127.7935712356887
# 0xc0314325637a1939,0xfa911155fefb5309 , // -256  error =  1.4336014514154617e-39  = +2 ** -129.0355516974762
# 0xf03d93eebc589f88,0x793555ab7eba27cb , // -255  error =  6.507231857869566e-40  = +2 ** -130.1750798364705
# 0x96267c7535b763b5,0x4bc1558b2f3458df , // -254  error =  1.2770257982897607e-39  = +2 ** -129.20240803015636
# 0xbbb01b9283253ca2,0x9eb1aaedfb016f17 , // -253  error =  2.279109978294247e-39  = +2 ** -128.36672515717484
# 0xea9c227723ee8bcb,0x465e15a979c1cadd , // -252  error =  3.080777322297836e-39  = +2 ** -127.93190129204567
# 0x92a1958a7675175f,0xbfacd89ec191eca , // -251  error =  2.439443447094965e-39  = +2 ** -128.26864366253335
# 0xb749faed14125d36,0xcef980ec671f667c , // -250  error =  3.871750464457767e-40  = +2 ** -130.92413782203752
# 0xe51c79a85916f484,0x82b7e12780e7401b , // -249  error =  3.871750464457767e-40  = +2 ** -130.92413782203752
# 0x8f31cc0937ae58d2,0xd1b2ecb8b0908811 , // -248  error =  1.0439009346535169e-39  = +2 ** -129.493210892785
# 0xb2fe3f0b8599ef07,0x861fa7e6dcb4aa16 , // -247  error =  4.19618519805067e-39  = +2 ** -127.48611734814163
# 0xdfbdcece67006ac9,0x67a791e093e1d49b , // -246  error =  2.514966924238855e-39  = +2 ** -128.224656274155
# 0x8bd6a141006042bd,0xe0c8bb2c5c6d24e1 , // -245  error =  3.187454233763581e-39  = +2 ** -127.88279107305017
# 0xaecc49914078536d,0x58fae9f773886e19 , // -244  error =  2.1114745385240193e-39  = +2 ** -128.476944850279
# 0xda7f5bf590966848,0xaf39a475506a899f , // -243  error =  1.2506907823323701e-39  = +2 ** -129.23247055533864
# 0x888f99797a5e012d,0x6d8406c952429604 , // -242  error =  4.693825807098967e-39  = +2 ** -127.32443139771017
# 0xaab37fd7d8f58178,0xc8e5087ba6d33b84 , // -241  error =  2.86612975397723e-40  = +2 ** -131.35801987145547
# 0xd5605fcdcf32e1d6,0xfb1e4a9a90880a65 , // -240  error =  2.86612975397723e-40  = +2 ** -131.35801987145547
# 0x855c3be0a17fcd26,0x5cf2eea09a550680 , // -239  error =  5.2226913469031164e-39  = +2 ** -127.17040225545526
# 0xa6b34ad8c9dfc06f,0xf42faa48c0ea481f , // -238  error =  7.097054072410424e-40  = +2 ** -130.04990349722752
# 0xd0601d8efc57b08b,0xf13b94daf124da27 , // -237  error =  1.6123025951734572e-39  = +2 ** -128.86607316791512
# 0x823c12795db6ce57,0x76c53d08d6b70859 , // -236  error =  5.2226913469031164e-39  = +2 ** -127.17040225545526
# 0xa2cb1717b52481ed,0x54768c4b0c64ca6f , // -235  error =  4.0673669463496254e-39  = +2 ** -127.53110054806672
# 0xcb7ddcdda26da268,0xa9942f5dcf7dfd0a , // -234  error =  1.2945883850212472e-39  = +2 ** -129.18270223534677
# 0xfe5d54150b090b02,0xd3f93b35435d7c4d , // -233  error =  2.7734036177297157e-39  = +2 ** -128.08353811130377
# 0x9efa548d26e5a6e1,0xc47bc5014a1a6db0 , // -232  error =  2.1818775246463282e-39  = +2 ** -128.42962557948846
# 0xc6b8e9b0709f109a,0x359ab6419ca1091c , // -231  error =  2.1818775246463282e-39  = +2 ** -128.42962557948846
# 0xf867241c8cc6d4c0,0xc30163d203c94b63 , // -230  error =  2.1818775246463282e-39  = +2 ** -128.42962557948846
# 0x9b407691d7fc44f8,0x79e0de63425dcf1e , // -229  error =  2.787600243963717e-39  = +2 ** -128.0761720143656
# 0xc21094364dfb5636,0x985915fc12f542e5 , // -228  error =  8.492875421480732e-40  = +2 ** -129.79087070767852
# 0xf294b943e17a2bc4,0x3e6f5b7b17b2939e , // -227  error =  7.396246142181573e-41  = +2 ** -133.3122586529037
# 0x979cf3ca6cec5b5a,0xa705992ceecf9c43 , // -226  error =  1.3144825905838277e-39  = +2 ** -129.16070066602637
# 0xbd8430bd08277231,0x50c6ff782a838354 , // -225  error =  2.3068986939134372e-39  = +2 ** -128.3492410502914
# 0xece53cec4a314ebd,0xa4f8bf5635246429 , // -224  error =  2.3068986939134372e-39  = +2 ** -128.3492410502914
# 0x940f4613ae5ed136,0x871b7795e136be9a , // -223  error =  4.2123376123062876e-39  = +2 ** -127.48057462984643
# 0xb913179899f68584,0x28e2557b59846e40 , // -222  error =  2.1798694326872474e-39  = +2 ** -128.43095397590577
# 0xe757dd7ec07426e5,0x331aeada2fe589d0 , // -221  error =  2.1798694326872474e-39  = +2 ** -128.43095397590577
# 0x9096ea6f3848984f,0x3ff0d2c85def7622 , // -220  error =  2.1798694326872474e-39  = +2 ** -128.43095397590577
# 0xb4bca50b065abe63,0xfed077a756b53aa , // -219  error =  9.862201675734988e-41  = +2 ** -132.8971421350476
# 0xe1ebce4dc7f16dfb,0xd3e8495912c62895 , // -218  error =  1.7636199495012678e-39  = +2 ** -128.73665599914654
# 0x8d3360f09cf6e4bd,0x64712dd7abbbd95d , // -217  error =  1.0976207764037006e-39  = +2 ** -129.42081600555548
# 0xb080392cc4349dec,0xbd8d794d96aacfb4 , // -216  error =  3.2022099447593156e-41  = +2 ** -134.5199839927919
# 0xdca04777f541c567,0xecf0d7a0fc5583a1 , // -215  error =  3.2022099447593156e-41  = +2 ** -134.5199839927919
# 0x89e42caaf9491b60,0xf41686c49db57245 , // -214  error =  2.0779715592033195e-39  = +2 ** -128.50001979211916
# 0xac5d37d5b79b6239,0x311c2875c522ced6 , // -213  error =  9.867985140002655e-40  = +2 ** -129.57436825237983
# 0xd77485cb25823ac7,0x7d633293366b828c , // -212  error =  2.732675386325152e-39  = +2 ** -128.10488160787133
# 0x86a8d39ef77164bc,0xae5dff9c02033198 , // -211  error =  5.5260783820449705e-39  = +2 ** -127.0889396750862
# 0xa8530886b54dbdeb,0xd9f57f830283fdfd , // -210  error =  1.0566335888932608e-39  = +2 ** -129.4757205236323
# 0xd267caa862a12d66,0xd072df63c324fd7c , // -209  error =  1.6274463026291902e-40  = +2 ** -132.1745138528462
# 0x8380dea93da4bc60,0x4247cb9e59f71e6e , // -208  error =  3.023189297880013e-39  = +2 ** -127.95912438404228
# 0xa46116538d0deb78,0x52d9be85f074e609 , // -207  error =  7.348335637863379e-40  = +2 ** -129.99970627192732
# 0xcd795be870516656,0x67902e276c921f8c , // -206  error =  3.480860444698748e-39  = +2 ** -127.75575172618271
# 0x806bd9714632dff6,0xba1cd8a3db53b7 , // -205  error =  5.517651050588438e-40  = +2 ** -130.41306957539342
# 0xa086cfcd97bf97f3,0x80e8a40eccd228a5 , // -204  error =  1.7234032409148054e-39  = +2 ** -128.7699353985779
# 0xc8a883c0fdaf7df0,0x6122cd128006b2ce , // -203  error =  7.860927322300361e-40  = +2 ** -129.90242428398125
# 0xfad2a4b13d1b5d6c,0x796b805720085f82 , // -202  error =  2.2857895461256672e-39  = +2 ** -128.36250312064954
# 0x9cc3a6eec6311a63,0xcbe3303674053bb1 , // -201  error =  1.0860320950091624e-39  = +2 ** -129.436128961529
# 0xc3f490aa77bd60fc,0xbedbfc4411068a9d , // -200  error =  1.2622613411595853e-40  = +2 ** -132.54111315572783
# 0xf4f1b4d515acb93b,0xee92fb5515482d45 , // -199  error =  2.4297604402596477e-39  = +2 ** -128.2743816208034
# 0x991711052d8bf3c5,0x751bdd152d4d1c4b , // -198  error =  1.8154846252879973e-39  = +2 ** -128.6948409881031
# 0xbf5cd54678eef0b6,0xd262d45a78a0635e , // -197  error =  2.798325929242638e-39  = +2 ** -128.0706316933878
# 0xef340a98172aace4,0x86fb897116c87c35 , // -196  error =  1.2257798429152128e-39  = +2 ** -129.26149581460933
# 0x9580869f0e7aac0e,0xd45d35e6ae3d4da1 , // -195  error =  5.967614083842428e-40  = +2 ** -130.29996955368966
# 0xbae0a846d2195712,0x8974836059cca10a , // -194  error =  3.616049894132899e-39  = +2 ** -127.70078111645981
# 0xe998d258869facd7,0x2bd1a438703fc94c , // -193  error =  2.0057627017336158e-39  = +2 ** -128.5510447672805
# 0x91ff83775423cc06,0x7b6306a34627ddd0 , // -192  error =  4.582222209572469e-39  = +2 ** -127.35914827843878
# 0xb67f6455292cbf08,0x1a3bc84c17b1d543 , // -191  error =  4.5988699703030366e-40  = +2 ** -130.6758443883509
# 0xe41f3d6a7377eeca,0x20caba5f1d9e4a94 , // -190  error =  1.2843540395387367e-39  = +2 ** -129.19415275618286
# 0x8e938662882af53e,0x547eb47b7282ee9d , // -189  error =  3.922648575565722e-39  = +2 ** -127.58336760837298
# 0xb23867fb2a35b28d,0xe99e619a4f23aa44 , // -188  error =  2.8673307611549282e-39  = +2 ** -128.03548736423454
# 0xdec681f9f4c31f31,0x6405fa00e2ec94d5 , // -187  error =  2.8673307611549282e-39  = +2 ** -128.03548736423454
# 0x8b3c113c38f9f37e,0xde83bc408dd3dd05 , // -186  error =  2.1919273599320198e-39  = +2 ** -128.42299571216375
# 0xae0b158b4738705e,0x9624ab50b148d446 , // -185  error =  1.1112819179753664e-39  = +2 ** -129.40297084421263
# 0xd98ddaee19068c76,0x3badd624dd9b0958 , // -184  error =  2.840314625106012e-39  = +2 ** -128.04914495294082
# 0x87f8a8d4cfa417c9,0xe54ca5d70a80e5d7 , // -183  error =  2.840314625106012e-39  = +2 ** -128.04914495294082
# 0xa9f6d30a038d1dbc,0x5e9fcf4ccd211f4d , // -182  error =  3.946895557669625e-39  = +2 ** -127.57447735731371
# 0xd47487cc8470652b,0x7647c32000696720 , // -181  error =  3.0616308116187346e-39  = +2 ** -127.94089537543077
# 0x84c8d4dfd2c63f3b,0x29ecd9f40041e074 , // -180  error =  3.0616308116187346e-39  = +2 ** -127.94089537543077
# 0xa5fb0a17c777cf09,0xf468107100525891 , // -179  error =  3.0616308116187346e-39  = +2 ** -127.94089537543077
# 0xcf79cc9db955c2cc,0x7182148d4066eeb5 , // -178  error =  2.1551197116626228e-39  = +2 ** -128.44742769086344
# 0x81ac1fe293d599bf,0xc6f14cd848405531 , // -177  error =  1.4299108316977333e-39  = +2 ** -129.03927051631567
# 0xa21727db38cb002f,0xb8ada00e5a506a7d , // -176  error =  2.695766237539101e-40  = +2 ** -131.44642839636523
# 0xca9cf1d206fdc03b,0xa6d90811f0e4851d , // -175  error =  3.0543787228190853e-39  = +2 ** -127.94431674271019
# 0xfd442e4688bd304a,0x908f4a166d1da664 , // -174  error =  2.311764829735039e-39  = +2 ** -128.34620105719392
# 0x9e4a9cec15763e2e,0x9a598e4e043287ff , // -173  error =  4.688129287603989e-39  = +2 ** -127.32618334415474
# 0xc5dd44271ad3cdba,0x40eff1e1853f29fe , // -172  error =  1.8364919381612488e-39  = +2 ** -128.67824313767142
# 0xf7549530e188c128,0xd12bee59e68ef47d , // -171  error =  3.1561868512512097e-40  = +2 ** -131.21894117778766
# 0x9a94dd3e8cf578b9,0x82bb74f8301958cf , // -170  error =  4.574063793626279e-39  = +2 ** -127.36171921371489
# 0xc13a148e3032d6e7,0xe36a52363c1faf02 , // -169  error =  1.6539871477969136e-39  = +2 ** -128.82924767642544
# 0xf18899b1bc3f8ca1,0xdc44e6c3cb279ac2 , // -168  error =  9.661293668791858e-41  = +2 ** -132.92683550829912
# 0x96f5600f15a7b7e5,0x29ab103a5ef8c0ba , // -167  error =  3.834311043349506e-39  = +2 ** -127.61622832591297
# 0xbcb2b812db11a5de,0x7415d448f6b6f0e8 , // -166  error =  1.8408720531299927e-39  = +2 ** -128.67480634264797
# 0xebdf661791d60f56,0x111b495b3464ad22 , // -165  error =  1.8408720531299927e-39  = +2 ** -128.67480634264797
# 0x936b9fcebb25c995,0xcab10dd900beec35 , // -164  error =  5.6507109938950425e-40  = +2 ** -130.37869139118223
# 0xb84687c269ef3bfb,0x3d5d514f40eea743 , // -163  error =  3.626993388366677e-39  = +2 ** -127.69642158518019
# 0xe65829b3046b0afa,0xcb4a5a3112a5113 , // -162  error =  1.1774555571849388e-39  = +2 ** -129.3195230939656
# 0x8ff71a0fe2c2e6dc,0x47f0e785eaba72ac , // -161  error =  1.830665645500069e-39  = +2 ** -128.68282738059514
# 0xb3f4e093db73a093,0x59ed216765690f57 , // -160  error =  1.830665645500069e-39  = +2 ** -128.68282738059514
# 0xe0f218b8d25088b8,0x306869c13ec3532d , // -159  error =  2.6667745585434357e-39  = +2 ** -128.14009983185574
# 0x8c974f7383725573,0x1e414218c73a13fc , // -158  error =  1.9978874281087422e-39  = +2 ** -128.55672040450614
# 0xafbd2350644eeacf,0xe5d1929ef90898fb , // -157  error =  1.9978874281087422e-39  = +2 ** -128.55672040450614
# 0xdbac6c247d62a583,0xdf45f746b74abf3a , // -156  error =  2.8540629550651496e-39  = +2 ** -128.0421785424022
# 0x894bc396ce5da772,0x6b8bba8c328eb784 , // -155  error =  1.484182111934898e-39  = +2 ** -128.9855275763938
# 0xab9eb47c81f5114f,0x66ea92f3f326565 , // -154  error =  1.484182111934898e-39  = +2 ** -128.9855275763938
# 0xd686619ba27255a2,0xc80a537b0efefebe , // -153  error =  6.0745837233153665e-40  = +2 ** -130.2743382478272
# 0x8613fd0145877585,0xbd06742ce95f5f37 , // -152  error =  2.0102163556969145e-39  = +2 ** -128.5478449163705
# 0xa798fc4196e952e7,0x2c48113823b73705 , // -151  error =  3.132422742389217e-39  = +2 ** -127.90791677303811
# 0xd17f3b51fca3a7a0,0xf75a15862ca504c6 , // -150  error =  2.234657633035375e-39  = +2 ** -128.3951418843919
# 0x82ef85133de648c4,0x9a984d73dbe722fc , // -149  error =  3.671081808001522e-39  = +2 ** -127.67899043616067
# 0xa3ab66580d5fdaf5,0xc13e60d0d2e0ebbb , // -148  error =  3.671081808001522e-39  = +2 ** -127.67899043616067
# 0xcc963fee10b7d1b3,0x318df905079926a9 , // -147  error =  9.131473920665197e-40  = +2 ** -129.68627604958823
# 0xffbbcfe994e5c61f,0xfdf17746497f7053 , // -146  error =  1.7769821448385253e-40  = +2 ** -132.04769461029127
# 0x9fd561f1fd0f9bd3,0xfeb6ea8bedefa634 , // -145  error =  7.660575565499863e-40  = +2 ** -129.93967100461091
# 0xc7caba6e7c5382c8,0xfe64a52ee96b8fc1 , // -144  error =  7.660575565499863e-40  = +2 ** -129.93967100461091
# 0xf9bd690a1b68637b,0x3dfdce7aa3c673b1 , // -143  error =  1.2957598705335055e-41  = +2 ** -135.82525350679583
# 0x9c1661a651213e2d,0x6bea10ca65c084f , // -142  error =  1.8203974975324983e-39  = +2 ** -128.6909421924338
# 0xc31bfa0fe5698db8,0x486e494fcff30a63 , // -141  error =  2.7843654435736518e-39  = +2 ** -128.0778471255443
# 0xf3e2f893dec3f126,0x5a89dba3c3efccfb , // -140  error =  4.70842373074883e-40  = +2 ** -130.6418796351135
# 0x986ddb5c6b3a76b7,0xf89629465a75e01d , // -139  error =  1.0877818585412213e-39  = +2 ** -129.43380643000646
# 0xbe89523386091465,0xf6bbb397f1135824 , // -138  error =  1.0067868179508004e-40  = +2 ** -132.86736556323686
# 0xee2ba6c0678b597f,0x746aa07ded582e2d , // -137  error =  1.0067868179508004e-40  = +2 ** -132.86736556323686
# 0x94db483840b717ef,0xa8c2a44eb4571cdd , // -136  error =  4.522900913617793e-39  = +2 ** -127.37794731043
# 0xba121a4650e4ddeb,0x92f34d62616ce414 , // -135  error =  3.512107260629745e-39  = +2 ** -127.74285879479547
# 0xe896a0d7e51e1566,0x77b020baf9c81d18 , // -134  error =  2.7756757106798857e-40  = +2 ** -131.4042847714987
# 0x915e2486ef32cd60,0xace1474dc1d122f , // -133  error =  2.7756757106798857e-40  = +2 ** -131.4042847714987
# 0xb5b5ada8aaff80b8,0xd819992132456bb , // -132  error =  1.3126202717277505e-39  = +2 ** -129.1627460816565
# 0xe3231912d5bf60e6,0x10e1fff697ed6c6a , // -131  error =  2.14066243225556e-39  = +2 ** -128.45713839003443
# 0x8df5efabc5979c8f,0xca8d3ffa1ef463c2 , // -130  error =  8.157949754110648e-40  = +2 ** -129.84891717408587
# 0xb1736b96b6fd83b3,0xbd308ff8a6b17cb3 , // -129  error =  2.935582906362257e-39  = +2 ** -128.00154869893447
# 0xddd0467c64bce4a0,0xac7cb3f6d05ddbdf , // -128  error =  3.918373892208263e-40  = +2 ** -130.9068687290022
# 0x8aa22c0dbef60ee4,0x6bcdf07a423aa96c , // -127  error =  3.7834980787427343e-39  = +2 ** -127.63547498807615
# 0xad4ab7112eb3929d,0x86c16c98d2c953c7 , // -126  error =  3.7834980787427343e-39  = +2 ** -127.63547498807615
# 0xd89d64d57a607744,0xe871c7bf077ba8b8 , // -125  error =  1.1787026691899089e-39  = +2 ** -129.31799585996845
# 0x87625f056c7c4a8b,0x11471cd764ad4973 , // -124  error =  1.1787026691899089e-39  = +2 ** -129.31799585996845
# 0xa93af6c6c79b5d2d,0xd598e40d3dd89bd0 , // -123  error =  2.2900820439324476e-39  = +2 ** -128.35979641571103
# 0xd389b47879823479,0x4aff1d108d4ec2c4 , // -122  error =  2.2900820439324476e-39  = +2 ** -128.35979641571103
# 0x843610cb4bf160cb,0xcedf722a585139bb , // -121  error =  5.135213243273347e-39  = +2 ** -127.19477151391268
# 0xa54394fe1eedb8fe,0xc2974eb4ee658829 , // -120  error =  1.721055804064268e-39  = +2 ** -128.77190182406483
# 0xce947a3da6a9273e,0x733d226229feea33 , // -119  error =  8.1061382027518e-40  = +2 ** -129.85810902317846
# 0x811ccc668829b887,0x806357d5a3f5260 , // -118  error =  1.53896740730645e-39  = +2 ** -128.9332330224272
# 0xa163ff802a3426a8,0xca07c2dcb0cf26f8 , // -117  error =  1.53896740730645e-39  = +2 ** -128.9332330224272
# 0xc9bcff6034c13052,0xfc89b393dd02f0b6 , // -116  error =  1.53896740730645e-39  = +2 ** -128.9332330224272
# 0xfc2c3f3841f17c67,0xbbac2078d443ace3 , // -115  error =  4.729926106640889e-41  = +2 ** -133.9572342451714
# 0x9d9ba7832936edc0,0xd54b944b84aa4c0e , // -114  error =  6.439665195624254e-40  = +2 ** -130.19013811230502
# 0xc5029163f384a931,0xa9e795e65d4df12 , // -113  error =  2.5533017467496783e-39  = +2 ** -128.20283165647157
# 0xf64335bcf065d37d,0x4d4617b5ff4a16d6 , // -112  error =  1.025833564999876e-39  = +2 ** -129.51839901881112
# 0x99ea0196163fa42e,0x504bced1bf8e4e46 , // -111  error =  2.247808110399718e-39  = +2 ** -128.38667681895882
# 0xc06481fb9bcf8d39,0xe45ec2862f71e1d7 , // -110  error =  2.926488377599709e-40  = +2 ** -131.32795324640526
# 0xf07da27a82c37088,0x5d767327bb4e5a4d , // -109  error =  1.0747125468158696e-39  = +2 ** -129.45124486659623
# 0x964e858c91ba2655,0x3a6a07f8d510f870 , // -108  error =  4.490615795711506e-40  = +2 ** -130.7102105009728
# 0xbbe226efb628afea,0x890489f70a55368c , // -107  error =  4.490615795711506e-40  = +2 ** -130.7102105009728
# 0xeadab0aba3b2dbe5,0x2b45ac74ccea842f , // -106  error =  4.490615795711506e-40  = +2 ** -130.7102105009728
# 0x92c8ae6b464fc96f,0x3b0b8bc90012929e , // -105  error =  3.652394531864112e-39  = +2 ** -127.68635308686747
# 0xb77ada0617e3bbcb,0x9ce6ebb40173745 , // -104  error =  1.6022614423966168e-39  = +2 ** -128.87508612784498
# 0xe55990879ddcaabd,0xcc420a6a101d0516 , // -103  error =  7.822082066096187e-40  = +2 ** -129.90957112317602
# 0x8f57fa54c2a9eab6,0x9fa946824a12232e , // -102  error =  2.0942933838688158e-39  = +2 ** -128.48873214095335
# 0xb32df8e9f3546564,0x47939822dc96abfa , // -101  error =  4.193629667483531e-39  = +2 ** -127.48699623556625
# 0xdff9772470297ebd,0x59787e2b93bc56f8 , // -100  error =  2.5141606405917588e-39  = +2 ** -128.22511886788092
# 0x8bfbea76c619ef36,0x57eb4edb3c55b65b , // -99  error =  2.5141606405917588e-39  = +2 ** -128.22511886788092
# 0xaefae51477a06b03,0xede622920b6b23f2 , // -98  error =  3.589020817802493e-39  = +2 ** -127.71160540920201
# 0xdab99e59958885c4,0xe95fab368e45ecee , // -97  error =  1.8692445342653183e-39  = +2 ** -128.65274038604784
# 0x88b402f7fd75539b,0x11dbcb0218ebb415 , // -96  error =  3.245065561095058e-39  = +2 ** -127.85694807485999
# 0xaae103b5fcd2a881,0xd652bdc29f26a11a , // -95  error =  2.1444087396312663e-39  = +2 ** -128.45461578061546
# 0xd59944a37c0752a2,0x4be76d3346f04960 , // -94  error =  3.833578252891992e-40  = +2 ** -130.93843216634684
# 0x857fcae62d8493a5,0x6f70a4400c562ddc , // -93  error =  3.833578252891992e-40  = +2 ** -130.93843216634684
# 0xa6dfbd9fb8e5b88e,0xcb4ccd500f6bb953 , // -92  error =  3.833578252891992e-40  = +2 ** -130.93843216634684
# 0xd097ad07a71f26b2,0x7e2000a41346a7a8 , // -91  error =  1.2850158934323375e-39  = +2 ** -129.19340949742593
# 0x825ecc24c873782f,0x8ed400668c0c28c9 , // -90  error =  1.2850158934323375e-39  = +2 ** -129.19340949742593
# 0xa2f67f2dfa90563b,0x728900802f0f32fb , // -89  error =  1.3089356620912052e-40  = +2 ** -132.48872960903114
# 0xcbb41ef979346bca,0x4f2b40a03ad2ffba , // -88  error =  1.0541914279876941e-39  = +2 ** -129.47905883445523
# 0xfea126b7d78186bc,0xe2f610c84987bfa9 , // -87  error =  2.5314680068334118e-39  = +2 ** -128.2152214492942
# 0x9f24b832e6b0f436,0xdd9ca7d2df4d7ca , // -86  error =  4.304199901448273e-39  = +2 ** -127.44945061757065
# 0xc6ede63fa05d3143,0x91503d1c79720dbc , // -85  error =  2.4132858805257545e-39  = +2 ** -128.2841968716731
# 0xf8a95fcf88747d94,0x75a44c6397ce912b , // -84  error =  2.4132858805257545e-39  = +2 ** -128.2841968716731
# 0x9b69dbe1b548ce7c,0xc986afbe3ee11abb , // -83  error =  3.01837836722096e-39  = +2 ** -127.96142203513406
# 0xc24452da229b021b,0xfbe85badce996169 , // -82  error =  1.1393443108397169e-40  = +2 ** -132.6889199988642
# 0xf2d56790ab41c2a2,0xfae27299423fb9c4 , // -81  error =  2.4374895799935626e-39  = +2 ** -128.26979964909822
# 0x97c560ba6b0919a5,0xdccd879fc967d41b , // -80  error =  4.9159484054971266e-39  = +2 ** -127.25772592637826
# 0xbdb6b8e905cb600f,0x5400e987bbc1c921 , // -79  error =  1.9417978148928498e-39  = +2 ** -128.59780270924074
# 0xed246723473e3813,0x290123e9aab23b69 , // -78  error =  1.1486909907317096e-39  = +2 ** -129.35520494970467
# 0x9436c0760c86e30b,0xf9a0b6720aaf6522 , // -77  error =  3.0521473687184464e-39  = +2 ** -127.94537107821633
# 0xb94470938fa89bce,0xf808e40e8d5b3e6a , // -76  error =  1.021793898865927e-39  = +2 ** -129.52409147406706
# 0xe7958cb87392c2c2,0xb60b1d1230b20e05 , // -75  error =  2.6460766747479426e-39  = +2 ** -128.15134083374642
# 0x90bd77f3483bb9b9,0xb1c6f22b5e6f48c3 , // -74  error =  1.9963635643951362e-39  = +2 ** -128.55782122202282
# 0xb4ecd5f01a4aa828,0x1e38aeb6360b1af4 , // -73  error =  3.0359045409596266e-39  = +2 ** -127.95306927232058
# 0xe2280b6c20dd5232,0x25c6da63c38de1b1 , // -72  error =  3.0359045409596266e-39  = +2 ** -127.95306927232058
# 0x8d590723948a535f,0x579c487e5a38ad0f , // -71  error =  5.031823215963447e-39  = +2 ** -127.22411446398871
# 0xb0af48ec79ace837,0x2d835a9df0c6d852 , // -70  error =  1.838353335957334e-39  = +2 ** -128.6767816178528
# 0xdcdb1b2798182244,0xf8e431456cf88e66 , // -69  error =  1.351693999540736e-40  = +2 ** -132.44235520845385
# 0x8a08f0f8bf0f156b,0x1b8e9ecb641b5900 , // -68  error =  1.4977165487566818e-39  = +2 ** -128.9724310890916
# 0xac8b2d36eed2dac5,0xe272467e3d222f40 , // -67  error =  1.4977165487566818e-39  = +2 ** -128.9724310890916
# 0xd7adf884aa879177,0x5b0ed81dcc6abb10 , // -66  error =  1.4977165487566818e-39  = +2 ** -128.9724310890916
# 0x86ccbb52ea94baea,0x98e947129fc2b4ea , // -65  error =  1.4977165487566818e-39  = +2 ** -128.9724310890916
# 0xa87fea27a539e9a5,0x3f2398d747b36225 , // -64  error =  3.730113797354875e-39  = +2 ** -127.65597605608501
# 0xd29fe4b18e88640e,0x8eec7f0d19a03aae , // -63  error =  2.837154897915598e-39  = +2 ** -128.05075078215762
# 0x83a3eeeef9153e89,0x1953cf68300424ad , // -62  error =  4.265889137018441e-39  = +2 ** -127.46234922755687
# 0xa48ceaaab75a8e2b,0x5fa8c3423c052dd8 , // -61  error =  3.1229017457361665e-39  = +2 ** -127.91230852131238
# 0xcdb02555653131b6,0x3792f412cb06794e , // -60  error =  3.1229017457361665e-39  = +2 ** -127.91230852131238
# 0x808e17555f3ebf11,0xe2bbd88bbee40bd1 , // -59  error =  4.585925606577478e-39  = +2 ** -127.3579827490666
# 0xa0b19d2ab70e6ed6,0x5b6aceaeae9d0ec5 , // -58  error =  3.415506517904429e-39  = +2 ** -127.78309615527444
# 0xc8de047564d20a8b,0xf245825a5a445276 , // -57  error =  2.4791712469659894e-39  = +2 ** -128.24533777262107
# 0xfb158592be068d2e,0xeed6e2f0f0d56713 , // -56  error =  9.810348134644858e-40  = +2 ** -129.58281946198434
# 0x9ced737bb6c4183d,0x55464dd69685606c , // -55  error =  1.580289386865087e-39  = +2 ** -128.89500692779575
# 0xc428d05aa4751e4c,0xaa97e14c3c26b887 , // -54  error =  1.580289386865087e-39  = +2 ** -128.89500692779575
# 0xf53304714d9265df,0xd53dd99f4b3066a9 , // -53  error =  2.347335240817857e-39  = +2 ** -128.32417180176824
# 0x993fe2c6d07b7fab,0xe546a8038efe402a , // -52  error =  4.188245290304504e-39  = +2 ** -127.488849762459
# 0xbf8fdb78849a5f96,0xde98520472bdd034 , // -51  error =  2.2246079041854137e-39  = +2 ** -128.40164462274632
# 0xef73d256a5c0f77c,0x963e66858f6d4441 , // -50  error =  2.2246079041854137e-39  = +2 ** -128.40164462274632
# 0x95a8637627989aad,0xdde7001379a44aa9 , // -49  error =  4.109699794859741e-39  = +2 ** -127.51616268876475
# 0xbb127c53b17ec159,0x5560c018580d5d53 , // -48  error =  3.104317453166766e-39  = +2 ** -127.92091960291094
# 0xe9d71b689dde71af,0xaab8f01e6e10b4a7 , // -47  error =  6.913998331036279e-40  = +2 ** -130.08760354014498
# 0x9226712162ab070d,0xcab3961304ca70e9 , // -46  error =  3.908623326521146e-39  = +2 ** -127.58853514159877
# 0xb6b00d69bb55c8d1,0x3d607b97c5fd0d23 , // -45  error =  2.87911180862754e-39  = +2 ** -128.02957188439757
# 0xe45c10c42a2b3b05,0x8cb89a7db77c506b , // -44  error =  4.082841656828863e-40  = +2 ** -130.84755017829573
# 0x8eb98a7a9a5b04e3,0x77f3608e92adb243 , // -43  error =  1.0671715371347939e-39  = +2 ** -129.46140360702867
# 0xb267ed1940f1c61c,0x55f038b237591ed4 , // -42  error =  2.1213913314578464e-39  = +2 ** -128.47018492232363
# 0xdf01e85f912e37a3,0x6b6c46dec52f6689 , // -41  error =  2.1213913314578464e-39  = +2 ** -128.47018492232363
# 0x8b61313bbabce2c6,0x2323ac4b3b3da016 , // -40  error =  4.145493336558107e-39  = +2 ** -127.50365190000696
# 0xae397d8aa96c1b77,0xabec975e0a0d081b , // -39  error =  1.9864511977844957e-39  = +2 ** -128.56500235021113
# 0xd9c7dced53c72255,0x96e7bd358c904a22 , // -38  error =  2.85006805329394e-39  = +2 ** -128.0441993325657
# 0x881cea14545c7575,0x7e50d64177da2e55 , // -37  error =  1.4682810844788289e-39  = +2 ** -129.00106751964307
# 0xaa242499697392d2,0xdde50bd1d5d0b9ea , // -36  error =  3.6285150942674003e-40  = +2 ** -131.01774452397294
# 0xd4ad2dbfc3d07787,0x955e4ec64b44e865 , // -35  error =  2.131538829510082e-39  = +2 ** -128.46330036398632
# 0x84ec3c97da624ab4,0xbd5af13bef0b113f , // -34  error =  1.4240639014767454e-39  = +2 ** -129.04518181534553
# 0xa6274bbdd0fadd61,0xecb1ad8aeacdd58f , // -33  error =  2.5560237863300845e-39  = +2 ** -128.2012944385551
# 0xcfb11ead453994ba,0x67de18eda5814af3 , // -32  error =  3.461591694212756e-39  = +2 ** -127.76376013635141
# 0x81ceb32c4b43fcf4,0x80eacf948770ced8 , // -31  error =  4.1860460205188926e-39  = +2 ** -127.48960752823724
# 0xa2425ff75e14fc31,0xa1258379a94d028e , // -30  error =  4.1860460205188926e-39  = +2 ** -127.48960752823724
# 0xcad2f7f5359a3b3e,0x96ee45813a04331 , // -29  error =  2.331442945175182e-39  = +2 ** -128.33397257597758
# 0xfd87b5f28300ca0d,0x8bca9d6e188853fd , // -28  error =  1.5896017150376977e-39  = +2 ** -128.8865303663675
# 0x9e74d1b791e07e48,0x775ea264cf55347e , // -27  error =  9.961287309277102e-40  = +2 ** -129.56079159991788
# 0xc612062576589dda,0x95364afe032a819e , // -26  error =  2.89524228007967e-39  = +2 ** -128.02151161952764
# 0xf79687aed3eec551,0x3a83ddbd83f52205 , // -25  error =  1.3759514407581023e-39  = +2 ** -129.09476614438518
# 0x9abe14cd44753b52,0xc4926a9672793543 , // -24  error =  7.682351050294752e-40  = +2 ** -129.93557590518088
# 0xc16d9a0095928a27,0x75b7053c0f178294 , // -23  error =  1.7405812421952785e-39  = +2 ** -128.75562654671396
# 0xf1c90080baf72cb1,0x5324c68b12dd6339 , // -22  error =  1.7405812421952785e-39  = +2 ** -128.75562654671396
# 0x971da05074da7bee,0xd3f6fc16ebca5e04 , // -21  error =  3.607485825553621e-39  = +2 ** -127.70420197448212
# 0xbce5086492111aea,0x88f4bb1ca6bcf585 , // -20  error =  3.607485825553621e-39  = +2 ** -127.70420197448212
# 0xec1e4a7db69561a5,0x2b31e9e3d06c32e6 , // -19  error =  2.810939869987395e-39  = +2 ** -128.0641431078632
# 0x9392ee8e921d5d07,0x3aff322e62439fd0 , // -18  error =  4.085413398893357e-39  = +2 ** -127.52471362998223
# 0xb877aa3236a4b449,0x9befeb9fad487c3 , // -17  error =  7.098106394278856e-42  = +2 ** -136.69354578599743
# 0xe69594bec44de15b,0x4c2ebe687989a9b4 , // -16  error =  8.227611648940944e-40  = +2 ** -129.83665009659634
# 0x901d7cf73ab0acd9,0xf9d37014bf60a11 , // -15  error =  3.432882952093504e-39  = +2 ** -127.77577503274192
# 0xb424dc35095cd80f,0x538484c19ef38c95 , // -14  error =  2.3888342372137403e-39  = +2 ** -128.29888895290193
# 0xe12e13424bb40e13,0x2865a5f206b06fba , // -13  error =  1.5535952653099292e-39  = +2 ** -128.9195849914446
# 0x8cbccc096f5088cb,0xf93f87b7442e45d4 , // -12  error =  2.1721291026383135e-40  = +2 ** -131.75801394179936
# 0xafebff0bcb24aafe,0xf78f69a51539d749 , // -11  error =  2.1721291026383135e-40  = +2 ** -131.75801394179936
# 0xdbe6fecebdedd5be,0xb573440e5a884d1c , // -10  error =  2.7830670319523392e-39  = +2 ** -128.07852004328487
# 0x89705f4136b4a597,0x31680a88f8953031 , // -9  error =  4.615596881793082e-41  = +2 ** -133.99253466337294
# 0xabcc77118461cefc,0xfdc20d2b36ba7c3e , // -8  error =  3.330449244579221e-39  = +2 ** -127.81947890492863
# 0xd6bf94d5e57a42bc,0x3d32907604691b4d , // -7  error =  1.5788261641731995e-39  = +2 ** -128.8963433678456
# 0x8637bd05af6c69b5,0xa63f9a49c2c1b110 , // -6  error =  8.78176932010791e-40  = +2 ** -129.74261215730735
# 0xa7c5ac471b478423,0xfcf80dc33721d54 , // -5  error =  8.78176932010791e-40  = +2 ** -129.74261215730735
# 0xd1b71758e219652b,0xd3c36113404ea4a9 , // -4  error =  8.78176932010791e-40  = +2 ** -129.74261215730735
# 0x83126e978d4fdf3b,0x645a1cac083126ea , // -3  error =  3.03057137321371e-39  = +2 ** -127.95560588064154
# 0xa3d70a3d70a3d70a,0x3d70a3d70a3d70a4 , // -2  error =  7.346839692639297e-40  = +2 ** -130.0
# 0xcccccccccccccccc,0xcccccccccccccccd , // -1  error =  7.346839692639297e-40  = +2 ** -130.0
# 0x8000000000000000,0x0 , // 0  error = 0
# 0xa000000000000000,0x0 , // 1  error = 0
# 0xc800000000000000,0x0 , // 2  error = 0
# 0xfa00000000000000,0x0 , // 3  error = 0
# 0x9c40000000000000,0x0 , // 4  error = 0
# 0xc350000000000000,0x0 , // 5  error = 0
# 0xf424000000000000,0x0 , // 6  error = 0
# 0x9896800000000000,0x0 , // 7  error = 0
# 0xbebc200000000000,0x0 , // 8  error = 0
# 0xee6b280000000000,0x0 , // 9  error = 0
# 0x9502f90000000000,0x0 , // 10  error = 0
# 0xba43b74000000000,0x0 , // 11  error = 0
# 0xe8d4a51000000000,0x0 , // 12  error = 0
# 0x9184e72a00000000,0x0 , // 13  error = 0
# 0xb5e620f480000000,0x0 , // 14  error = 0
# 0xe35fa931a0000000,0x0 , // 15  error = 0
# 0x8e1bc9bf04000000,0x0 , // 16  error = 0
# 0xb1a2bc2ec5000000,0x0 , // 17  error = 0
# 0xde0b6b3a76400000,0x0 , // 18  error = 0
# 0x8ac7230489e80000,0x0 , // 19  error = 0
# 0xad78ebc5ac620000,0x0 , // 20  error = 0
# 0xd8d726b7177a8000,0x0 , // 21  error = 0
# 0x878678326eac9000,0x0 , // 22  error = 0
# 0xa968163f0a57b400,0x0 , // 23  error = 0
# 0xd3c21bcecceda100,0x0 , // 24  error = 0
# 0x84595161401484a0,0x0 , // 25  error = 0
# 0xa56fa5b99019a5c8,0x0 , // 26  error = 0
# 0xcecb8f27f4200f3a,0x0 , // 27  error = 0
# 0x813f3978f8940984,0x4000000000000000 , // 28  error = 0
# 0xa18f07d736b90be5,0x5000000000000000 , // 29  error = 0
# 0xc9f2c9cd04674ede,0xa400000000000000 , // 30  error = 0
# 0xfc6f7c4045812296,0x4d00000000000000 , // 31  error = 0
# 0x9dc5ada82b70b59d,0xf020000000000000 , // 32  error = 0
# 0xc5371912364ce305,0x6c28000000000000 , // 33  error = 0
# 0xf684df56c3e01bc6,0xc732000000000000 , // 34  error = 0
# 0x9a130b963a6c115c,0x3c7f400000000000 , // 35  error = 0
# 0xc097ce7bc90715b3,0x4b9f100000000000 , // 36  error = 0
# 0xf0bdc21abb48db20,0x1e86d40000000000 , // 37  error = 0
# 0x96769950b50d88f4,0x1314448000000000 , // 38  error = 0
# 0xbc143fa4e250eb31,0x17d955a000000000 , // 39  error = 0
# 0xeb194f8e1ae525fd,0x5dcfab0800000000 , // 40  error = 0
# 0x92efd1b8d0cf37be,0x5aa1cae500000000 , // 41  error = 0
# 0xb7abc627050305ad,0xf14a3d9e40000000 , // 42  error = 0
# 0xe596b7b0c643c719,0x6d9ccd05d0000000 , // 43  error = 0
# 0x8f7e32ce7bea5c6f,0xe4820023a2000000 , // 44  error = 0
# 0xb35dbf821ae4f38b,0xdda2802c8a800000 , // 45  error = 0
# 0xe0352f62a19e306e,0xd50b2037ad200000 , // 46  error = 0
# 0x8c213d9da502de45,0x4526f422cc340000 , // 47  error = 0
# 0xaf298d050e4395d6,0x9670b12b7f410000 , // 48  error = 0
# 0xdaf3f04651d47b4c,0x3c0cdd765f114000 , // 49  error = 0
# 0x88d8762bf324cd0f,0xa5880a69fb6ac800 , // 50  error = 0
# 0xab0e93b6efee0053,0x8eea0d047a457a00 , // 51  error = 0
# 0xd5d238a4abe98068,0x72a4904598d6d880 , // 52  error = 0
# 0x85a36366eb71f041,0x47a6da2b7f864750 , // 53  error = 0
# 0xa70c3c40a64e6c51,0x999090b65f67d924 , // 54  error = 0
# 0xd0cf4b50cfe20765,0xfff4b4e3f741cf6d , // 55  error = 0
# 0x82818f1281ed449f,0xbff8f10e7a8921a5 , // 56  error =  5.044031582654955e-39  = +2 ** -127.22061839163469
# 0xa321f2d7226895c7,0xaff72d52192b6a0e , // 57  error =  3.8911100780481085e-39  = +2 ** -127.59501390641618
# 0xcbea6f8ceb02bb39,0x9bf4f8a69f764491 , // 58  error =  2.0464356706771533e-39  = +2 ** -128.52208238396233
# 0xfee50b7025c36a08,0x2f236d04753d5b5 , // 59  error =  1.3085659077287713e-39  = +2 ** -129.16720911106347
# 0x9f4f2726179a2245,0x1d762422c946591 , // 60  error =  7.182700973700656e-40  = +2 ** -130.03259734021773
# 0xc722f0ef9d80aad6,0x424d3ad2b7b97ef6 , // 61  error =  3.551689987091853e-39  = +2 ** -127.7266900405419
# 0xf8ebad2b84e0d58b,0xd2e0898765a7deb3 , // 62  error =  2.0405327125735664e-39  = +2 ** -128.5262498614204
# 0x9b934c3b330c8577,0x63cc55f49f88eb30 , // 63  error =  2.644995622380881e-39  = +2 ** -128.1519303660087
# 0xc2781f49ffcfa6d5,0x3cbf6b71c76b25fc , // 64  error =  2.644995622380881e-39  = +2 ** -128.1519303660087
# 0xf316271c7fc3908a,0x8bef464e3945ef7b , // 65  error =  2.644995622380881e-39  = +2 ** -128.1519303660087
# 0x97edd871cfda3a56,0x97758bf0e3cbb5ad , // 66  error =  3.263965642023571e-39  = +2 ** -127.84856982967734
# 0xbde94e8e43d0c8ec,0x3d52eeed1cbea318 , // 67  error =  2.273613610595267e-39  = +2 ** -128.3702086044432
# 0xed63a231d4c4fb27,0x4ca7aaa863ee4bde , // 68  error =  2.273613610595267e-39  = +2 ** -128.3702086044432
# 0x945e455f24fb1cf8,0x8fe8caa93e74ef6b , // 69  error =  3.541264210823496e-39  = +2 ** -127.73093121456685
# 0xb975d6b6ee39e436,0xb3e2fd538e122b45 , // 70  error =  4.9890277027574565e-40  = +2 ** -130.55836511522014
# 0xe7d34c64a9c85d44,0x60dbbca87196b617 , // 71  error =  2.932791922713946e-39  = +2 ** -128.00292098297888
# 0x90e40fbeea1d3a4a,0xbc8955e946fe31ce , // 72  error =  9.856806007633857e-40  = +2 ** -129.57600356303394
# 0xb51d13aea4a488dd,0x6babab6398bdbe42 , // 73  error =  3.062599344177317e-39  = +2 ** -127.9404390577891
# 0xe264589a4dcdab14,0xc696963c7eed2dd2 , // 74  error =  1.401064349446172e-39  = +2 ** -129.06867248181564
# 0x8d7eb76070a08aec,0xfc1e1de5cf543ca3 , // 75  error =  7.18363536612561e-41  = +2 ** -133.35433776814705
# 0xb0de65388cc8ada8,0x3b25a55f43294bcc , // 76  error =  1.1352187502891888e-39  = +2 ** -129.37222537705637
# 0xdd15fe86affad912,0x49ef0eb713f39ebf , // 77  error =  1.1352187502891888e-39  = +2 ** -129.37222537705637
# 0x8a2dbf142dfcc7ab,0x6e3569326c784338 , // 78  error =  4.538042419498573e-39  = +2 ** -127.37312560589521
# 0xacb92ed9397bf996,0x49c2c37f07965405 , // 79  error =  1.824281229105611e-40  = +2 ** -132.00979564463157
# 0xd7e77a8f87daf7fb,0xdc33745ec97be907 , // 80  error =  2.7957967008633684e-39  = +2 ** -128.07193624308397
# 0x86f0ac99b4e8dafd,0x69a028bb3ded71a4 , // 81  error =  7.051018385011226e-40  = +2 ** -130.05929215317457
# 0xa8acd7c0222311bc,0xc40832ea0d68ce0d , // 82  error =  7.051018385011226e-40  = +2 ** -130.05929215317457
# 0xd2d80db02aabd62b,0xf50a3fa490c30191 , // 83  error =  3.3811912623247975e-39  = +2 ** -127.79766407378635
# 0x83c7088e1aab65db,0x792667c6da79e0fb , // 84  error =  5.5220628013837374e-39  = +2 ** -127.08998840508795
# 0xa4b8cab1a1563f52,0x577001b891185939 , // 85  error =  2.0966683388894334e-39  = +2 ** -128.4870970335847
# 0xcde6fd5e09abcf26,0xed4c0226b55e6f87 , // 86  error =  1.1832298155576192e-39  = +2 ** -129.3124653889203
# 0x80b05e5ac60b6178,0x544f8158315b05b5 , // 87  error =  4.8369839088848764e-39  = +2 ** -127.28108796220533
# 0xa0dc75f1778e39d6,0x696361ae3db1c722 , // 88  error =  3.6677825990201544e-39  = +2 ** -127.68028757220051
# 0xc913936dd571c84c,0x3bc3a19cd1e38ea , // 89  error =  1.7970605032365982e-39  = +2 ** -128.70955671844266
# 0xfb5878494ace3a5f,0x4ab48a04065c724 , // 90  error =  3.0048282660975376e-40  = +2 ** -131.28984125604867
# 0x9d174b2dcec0e47b,0x62eb0d64283f9c77 , // 91  error =  2.695007109212705e-39  = +2 ** -128.12490662191047
# 0xc45d1df942711d9a,0x3ba5d0bd324f8395 , // 92  error =  3.652816822253886e-39  = +2 ** -127.68618629189815
# 0xf5746577930d6500,0xca8f44ec7ee3647a , // 93  error =  2.8865690518209414e-39  = +2 ** -128.0258399630397
# 0x9968bf6abbe85f20,0x7e998b13cf4e1ecc , // 94  error =  1.66057261912823e-39  = +2 ** -128.82351488534536
# 0xbfc2ef456ae276e8,0x9e3fedd8c321a67f , // 95  error =  1.66057261912823e-39  = +2 ** -128.82351488534536
# 0xefb3ab16c59b14a2,0xc5cfe94ef3ea101f , // 96  error =  2.4452103360515654e-39  = +2 ** -128.2652371300199
# 0x95d04aee3b80ece5,0xbba1f1d158724a13 , // 97  error =  5.62079815435561e-40  = +2 ** -130.38634878754462
# 0xbb445da9ca61281f,0x2a8a6e45ae8edc98 , // 98  error =  1.56641609309743e-39  = +2 ** -128.90772820846874
# 0xea1575143cf97226,0xf52d09d71a3293be , // 99  error =  1.56641609309743e-39  = +2 ** -128.90772820846874
# 0x924d692ca61be758,0x593c2626705f9c57 , // 100  error =  2.8519665285046222e-39  = +2 ** -128.04323865060786
# 0xb6e0c377cfa2e12e,0x6f8b2fb00c77836d , // 101  error =  3.880406876830376e-39  = +2 ** -127.59898776767676
# 0xe498f455c38b997a,0xb6dfb9c0f956448 , // 102  error =  3.057654598169773e-39  = +2 ** -127.94277025586126
# 0x8edf98b59a373fec,0x4724bd4189bd5ead , // 103  error =  3.057654598169773e-39  = +2 ** -127.94277025586126
# 0xb2977ee300c50fe7,0x58edec91ec2cb658 , // 104  error =  2.004531681484201e-39  = +2 ** -128.5519304812432
# 0xdf3d5e9bc0f653e1,0x2f2967b66737e3ee , // 105  error =  2.004531681484201e-39  = +2 ** -128.5519304812432
# 0x8b865b215899f46c,0xbd79e0d20082ee75 , // 106  error =  3.352529014841733e-39  = +2 ** -127.80994588245586
# 0xae67f1e9aec07187,0xecd8590680a3aa12 , // 107  error =  2.2741311481557073e-39  = +2 ** -128.36988024438136
# 0xda01ee641a708de9,0xe80e6f4820cc9496 , // 108  error =  5.4869456145806646e-40  = +2 ** -130.42112051929735
# 0x884134fe908658b2,0x3109058d147fdcde , // 109  error =  1.9290438308161794e-39  = +2 ** -128.60730977661734
# 0xaa51823e34a7eede,0xbd4b46f0599fd416 , // 110  error =  4.13760266178916e-39  = +2 ** -127.50640059223612
# 0xd4e5e2cdc1d1ea96,0x6c9e18ac7007c91b , // 111  error =  2.3707555970107754e-39  = +2 ** -128.3098487586454
# 0x850fadc09923329e,0x3e2cf6bc604ddb1 , // 112  error =  3.077494422922129e-39  = +2 ** -127.93343945836689
# 0xa6539930bf6bff45,0x84db8346b786151d , // 113  error =  1.946712301463963e-39  = +2 ** -128.5941560121935
# 0xcfe87f7cef46ff16,0xe612641865679a64 , // 114  error =  1.0420866042974303e-39  = +2 ** -129.49572052049697
# 0x81f14fae158c5f6e,0x4fcb7e8f3f60c07f , // 115  error =  3.9368888352303354e-39  = +2 ** -127.57813972448969
# 0xa26da3999aef7749,0xe3be5e330f38f09e , // 116  error =  4.631261581108494e-40  = +2 ** -130.66571855041354
# 0xcb090c8001ab551c,0x5cadf5bfd3072cc6 , // 117  error =  2.3157995859079084e-39  = +2 ** -128.34368529569434
# 0xfdcb4fa002162a63,0x73d9732fc7c8f7f7 , // 118  error =  8.336608436702611e-40  = +2 ** -129.81766322078346
# 0x9e9f11c4014dda7e,0x2867e7fddcdd9afb , // 119  error =  3.7979383281455557e-39  = +2 ** -127.62997922176558
# 0xc646d63501a1511d,0xb281e1fd541501b9 , // 120  error =  9.522319430492729e-40  = +2 ** -129.62581076993376
# 0xf7d88bc24209a565,0x1f225a7ca91a4227 , // 121  error =  1.9337690702359754e-40  = +2 ** -131.92570827633514
# 0x9ae757596946075f,0x3375788de9b06959 , // 122  error =  3.228797051126299e-39  = +2 ** -127.86419893866896
# 0xc1a12d2fc3978937,0x52d6b1641c83af , // 123  error =  2.2574626050134347e-39  = +2 ** -128.38049361102216
# 0xf209787bb47d6b84,0xc0678c5dbd23a49b , // 124  error =  3.034530161903726e-39  = +2 ** -127.95372254016026
# 0x9745eb4d50ce6332,0xf840b7ba963646e1 , // 125  error =  3.6561842074159595e-39  = +2 ** -127.68485694190953
# 0xbd176620a501fbff,0xb650e5a93bc3d899 , // 126  error =  2.6615377345963863e-39  = +2 ** -128.1429356800401
# 0xec5d3fa8ce427aff,0xa3e51f138ab4cebf , // 127  error =  1.8658205563407276e-39  = +2 ** -128.6553854576789
# 0x93ba47c980e98cdf,0xc66f336c36b10138 , // 128  error =  5.048689269363362e-39  = +2 ** -127.21928681373973
# 0xb8a8d9bbe123f017,0xb80b0047445d4185 , // 129  error =  9.7461731669439e-40  = +2 ** -129.59228793938416
# 0xe6d3102ad96cec1d,0xa60dc059157491e6 , // 130  error =  1.5980292616059558e-40  = +2 ** -132.20082996971465
# 0x9043ea1ac7e41392,0x87c89837ad68db30 , // 131  error =  1.4635059510146667e-39  = +2 ** -129.0057670884567
# 0xb454e4a179dd1877,0x29babe4598c311fc , // 132  error =  1.4635059510146667e-39  = +2 ** -129.0057670884567
# 0xe16a1dc9d8545e94,0xf4296dd6fef3d67b , // 133  error =  1.4635059510146667e-39  = +2 ** -129.0057670884567
# 0x8ce2529e2734bb1d,0x1899e4a65f58660d , // 134  error =  2.131001899739951e-39  = +2 ** -128.46366382135596
# 0xb01ae745b101e9e4,0x5ec05dcff72e7f90 , // 135  error =  1.063008381779496e-39  = +2 ** -129.46704272809933
# 0xdc21a1171d42645d,0x76707543f4fa1f74 , // 136  error =  1.063008381779496e-39  = +2 ** -129.46704272809933
# 0x899504ae72497eba,0x6a06494a791c53a9 , // 137  error =  3.797071787758261e-39  = +2 ** -127.63030842567862
# 0xabfa45da0edbde69,0x487db9d17636893 , // 138  error =  2.703446425366755e-39  = +2 ** -128.12039593402392
# 0xd6f8d7509292d603,0x45a9d2845d3c42b7 , // 139  error =  7.874555562714067e-41  = +2 ** -133.2218533898105
# 0x865b86925b9bc5c2,0xb8a2392ba45a9b3 , // 140  error =  3.57834671527996e-39  = +2 ** -127.71590251998613
# 0xa7f26836f282b732,0x8e6cac7768d7141f , // 141  error =  2.1872960201325344e-40  = +2 ** -131.74797531316193
# 0xd1ef0244af2364ff,0x3207d795430cd927 , // 142  error =  1.1146274988843752e-39  = +2 ** -129.3986340490274
# 0x8335616aed761f1f,0x7f44e6bd49e807b9 , // 143  error =  4.698219086368862e-39  = +2 ** -127.32308171023527
# 0xa402b9c5a8d3a6e7,0x5f16206c9c6209a7 , // 144  error =  3.551469778373826e-39  = +2 ** -127.72677949200747
# 0xcd036837130890a1,0x36dba887c37a8c10 , // 145  error =  7.992714391857403e-40  = +2 ** -129.8784382579687
# 0x802221226be55a64,0xc2494954da2c978a , // 146  error =  7.992714391857403e-40  = +2 ** -129.8784382579687
# 0xa02aa96b06deb0fd,0xf2db9baa10b7bd6d , // 147  error =  3.147814021959574e-39  = +2 ** -127.90084539404464
# 0xc83553c5c8965d3d,0x6f92829494e5acc8 , // 148  error =  2.20839698885004e-39  = +2 ** -128.41219616147842
# 0xfa42a8b73abbf48c,0xcb772339ba1f17fa , // 149  error =  2.20839698885004e-39  = +2 ** -128.41219616147842
# 0x9c69a97284b578d7,0xff2a760414536efc , // 150  error =  1.0059431864698376e-39  = +2 ** -129.5466468735082
# 0xc38413cf25e2d70d,0xfef5138519684abb , // 151  error =  1.0059431864698376e-39  = +2 ** -129.5466468735082
# 0xf46518c2ef5b8cd1,0x7eb258665fc25d6a , // 152  error =  1.7755136199931672e-39  = +2 ** -128.72695927326924
# 0x98bf2f79d5993802,0xef2f773ffbd97a62 , // 153  error =  5.442009263558398e-40  = +2 ** -130.43298438310418
# 0xbeeefb584aff8603,0xaafb550ffacfd8fb , // 154  error =  2.5143012361755637e-39  = +2 ** -128.22503819249488
# 0xeeaaba2e5dbf6784,0x95ba2a53f983cf39 , // 155  error =  1.50180864391895e-40  = +2 ** -132.29042279493015
# 0x952ab45cfa97a0b2,0xdd945a747bf26184 , // 156  error =  2.04147716181883e-39  = +2 ** -128.5255822725077
# 0xba756174393d88df,0x94f971119aeef9e5 , // 157  error =  2.04147716181883e-39  = +2 ** -128.5255822725077
# 0xe912b9d1478ceb17,0x7a37cd5601aab85e , // 158  error =  1.2345240749166711e-39  = +2 ** -129.2512407293154
# 0x91abb422ccb812ee,0xac62e055c10ab33b , // 159  error =  2.5256490139601252e-39  = +2 ** -128.21854153693772
# 0xb616a12b7fe617aa,0x577b986b314d600a , // 160  error =  3.5585489651948887e-39  = +2 ** -127.723906613197
# 0xe39c49765fdf9d94,0xed5a7e85fda0b80c , // 161  error =  1.9059090432192674e-39  = +2 ** -128.624716430272
# 0x8e41ade9fbebc27d,0x14588f13be847308 , // 162  error =  4.5501329183802614e-39  = +2 ** -127.36928701070521
# 0xb1d219647ae6b31c,0x596eb2d8ae258fc9 , // 163  error =  3.193747181226707e-40  = +2 ** -131.20187368275367
# 0xde469fbd99a05fe3,0x6fca5f8ed9aef3bc , // 164  error =  2.8578296382772254e-39  = +2 ** -128.04027578394184
# 0x8aec23d680043bee,0x25de7bb9480d5855 , // 165  error =  1.5014439011236704e-40  = +2 ** -132.29077322341837
# 0xada72ccc20054ae9,0xaf561aa79a10ae6b , // 166  error =  3.3993666879101966e-39  = +2 ** -127.78992970757248
# 0xd910f7ff28069da4,0x1b2ba1518094da05 , // 167  error =  7.99988849671933e-40  = +2 ** -129.87714390378838
# 0x87aa9aff79042286,0x90fb44d2f05d0843 , // 168  error =  1.0682142614172931e-40  = +2 ** -132.7819227450222
# 0xa99541bf57452b28,0x353a1607ac744a54 , // 169  error =  1.2158893037900552e-39  = +2 ** -129.2731838107587
# 0xd3fa922f2d1675f2,0x42889b8997915ce9 , // 170  error =  1.2158893037900552e-39  = +2 ** -129.2731838107587
# 0x847c9b5d7c2e09b7,0x69956135febada12 , // 171  error =  3.345299628874841e-39  = +2 ** -127.81306026590406
# 0xa59bc234db398c25,0x43fab9837e699096 , // 172  error =  1.0739286154510696e-39  = +2 ** -129.45229760072647
# 0xcf02b2c21207ef2e,0x94f967e45e03f4bc , // 173  error =  2.891025426190087e-39  = +2 ** -128.02361440342239
# 0x8161afb94b44f57d,0x1d1be0eebac278f6 , // 174  error =  5.7983803233725144e-39  = +2 ** -127.01954573584383
# 0xa1ba1ba79e1632dc,0x6462d92a69731733 , // 175  error =  3.4724964056265724e-39  = +2 ** -127.75922249973017
# 0xca28a291859bbf93,0x7d7b8f7503cfdcff , // 176  error =  6.814357043314418e-40  = +2 ** -130.10854625499826
# 0xfcb2cb35e702af78,0x5cda735244c3d43f , // 177  error =  1.4257185580101433e-39  = +2 ** -129.0435064839283
# 0x9defbf01b061adab,0x3a0888136afa64a8 , // 178  error =  4.402849972724949e-39  = +2 ** -127.41675801538146
# 0xc56baec21c7a1916,0x88aaa1845b8fdd1 , // 179  error =  5.9212176188999765e-40  = +2 ** -130.3112299182686
# 0xf6c69a72a3989f5b,0x8aad549e57273d46 , // 180  error =  2.8785586883909686e-39  = +2 ** -128.02984907421774
# 0x9a3c2087a63f6399,0x36ac54e2f678864c , // 181  error =  4.097991715858153e-39  = +2 ** -127.52027863268121
# 0xc0cb28a98fcf3c7f,0x84576a1bb416a7de , // 182  error =  1.958060279631627e-40  = +2 ** -131.9076986159528
# 0xf0fdf2d3f3c30b9f,0x656d44a2a11c51d6 , // 183  error =  1.756680303121159e-39  = +2 ** -128.74234404031841
# 0x969eb7c47859e743,0x9f644ae5a4b1b326 , // 184  error =  3.0053797232475555e-39  = +2 ** -127.96764841674673
# 0xbc4665b596706114,0x873d5d9f0dde1fef , // 185  error =  1.0074606510453207e-39  = +2 ** -129.54447220890142
# 0xeb57ff22fc0c7959,0xa90cb506d155a7eb , // 186  error =  1.8066282799262148e-39  = +2 ** -128.70189600341064
# 0x9316ff75dd87cbd8,0x9a7f12442d588f3 , // 187  error =  2.44596238303093e-39  = +2 ** -128.26479348408117
# 0xb7dcbf5354e9bece,0xc11ed6d538aeb30 , // 188  error =  3.468896947998474e-39  = +2 ** -127.76071871810329
# 0xe5d3ef282a242e81,0x8f1668c8a86da5fb , // 189  error =  1.9550634010233236e-40  = +2 ** -131.90990840184483
# 0x8fa475791a569d10,0xf96e017d694487bd , // 190  error =  8.501844616815607e-40  = +2 ** -129.78934790356024
# 0xb38d92d760ec4455,0x37c981dcc395a9ad , // 191  error =  3.992639445261857e-39  = +2 ** -127.55785290512476
# 0xe070f78d3927556a,0x85bbe253f47b1418 , // 192  error =  3.154651449640444e-39  = +2 ** -127.8977150867317
# 0x8c469ab843b89562,0x93956d7478ccec8f , // 193  error =  3.154651449640444e-39  = +2 ** -127.8977150867317
# 0xaf58416654a6babb,0x387ac8d1970027b3 , // 194  error =  4.227276084035852e-39  = +2 ** -127.47546736253167
# 0xdb2e51bfe9d0696a,0x6997b05fcc0319f , // 195  error =  1.6529769614868737e-39  = +2 ** -128.83012908352697
# 0x88fcf317f22241e2,0x441fece3bdf81f04 , // 196  error =  5.085375791552179e-39  = +2 ** -127.20884131244831
# 0xab3c2fddeeaad25a,0xd527e81cad7626c4 , // 197  error =  6.919052890685884e-40  = +2 ** -130.08654922633553
# 0xd60b3bd56a5586f1,0x8a71e223d8d3b075 , // 198  error =  6.919052890685884e-40  = +2 ** -130.08654922633553
# 0x85c7056562757456,0xf6872d5667844e4a , // 199  error =  5.6125922518502096e-39  = +2 ** -127.06652844757865
# 0xa738c6bebb12d16c,0xb428f8ac016561dc , // 200  error =  3.3631353545786114e-39  = +2 ** -127.8053888570832
# 0xd106f86e69d785c7,0xe13336d701beba53 , // 201  error =  3.3631353545786114e-39  = +2 ** -127.8053888570832
# 0x82a45b450226b39c,0xecc0024661173474 , // 202  error =  4.0829615617055225e-39  = +2 ** -127.5255797149686
# 0xa34d721642b06084,0x27f002d7f95d0191 , // 203  error =  4.0829615617055225e-39  = +2 ** -127.5255797149686
# 0xcc20ce9bd35c78a5,0x31ec038df7b441f5 , // 204  error =  3.161584016583076e-39  = +2 ** -127.89454814211145
# 0xff290242c83396ce,0x7e67047175a15272 , // 205  error =  2.4244819804851188e-39  = +2 ** -128.2775191693977
# 0x9f79a169bd203e41,0xf0062c6e984d387 , // 206  error =  1.245118722728387e-39  = +2 ** -129.2389123900203
# 0xc75809c42c684dd1,0x52c07b78a3e60869 , // 207  error =  2.1886093289337723e-39  = +2 ** -128.4251812470067
# 0xf92e0c3537826145,0xa7709a56ccdf8a83 , // 208  error =  1.4338168439694642e-39  = +2 ** -129.03533495493076
# 0x9bbcc7a142b17ccb,0x88a66076400bb692 , // 209  error =  2.0376508319409108e-39  = +2 ** -128.52828884546506
# 0xc2abf989935ddbfe,0x6acff893d00ea436 , // 210  error =  1.0538207043228157e-40  = +2 ** -132.80149436588928
# 0xf356f7ebf83552fe,0x583f6b8c4124d44 , // 211  error =  1.651197079639185e-39  = +2 ** -128.8316833763284
# 0x98165af37b2153de,0xc3727a337a8b704b , // 212  error =  4.12450109437023e-39  = +2 ** -127.51097608117797
# 0xbe1bf1b059e9a8d6,0x744f18c0592e4c5d , // 213  error =  1.1565362766929758e-39  = +2 ** -129.34538518138248
# 0xeda2ee1c7064130c,0x1162def06f79df74 , // 214  error =  3.6507899197904133e-40  = +2 ** -131.0089151424425
# 0x9485d4d1c63e8be7,0x8addcb5645ac2ba9 , // 215  error =  2.897742303063632e-39  = +2 ** -128.02026639923292
# 0xb9a74a0637ce2ee1,0x6d953e2bd7173693 , // 216  error =  1.8846769786297957e-39  = +2 ** -128.64087842446764
# 0xe8111c87c5c1ba99,0xc8fa8db6ccdd0438 , // 217  error =  2.6951292381768645e-39  = +2 ** -128.12484124514089
# 0x910ab1d4db9914a0,0x1d9c9892400a22a3 , // 218  error =  2.6951292381768645e-39  = +2 ** -128.12484124514089
# 0xb54d5e4a127f59c8,0x2503beb6d00cab4c , // 219  error =  3.732508130397113e-39  = +2 ** -127.65505029766973
# 0xe2a0b5dc971f303a,0x2e44ae64840fd61e , // 220  error =  4.128956752923184e-40  = +2 ** -130.83134648782323
# 0x8da471a9de737e24,0x5ceaecfed289e5d3 , // 221  error =  1.740740657334236e-39  = +2 ** -128.7554944202188
# 0xb10d8e1456105dad,0x7425a83e872c5f48 , // 222  error =  2.8030166429677705e-39  = +2 ** -128.06821539018043
# 0xdd50f1996b947518,0xd12f124e28f7771a , // 223  error =  2.8030166429677705e-39  = +2 ** -128.06821539018043
# 0x8a5296ffe33cc92f,0x82bd6b70d99aaa70 , // 224  error =  1.4433033813568465e-39  = +2 ** -129.0258211154176
# 0xace73cbfdc0bfb7b,0x636cc64d1001550c , // 225  error =  1.4433033813568465e-39  = +2 ** -129.0258211154176
# 0xd8210befd30efa5a,0x3c47f7e05401aa4f , // 226  error =  1.4433033813568465e-39  = +2 ** -129.0258211154176
# 0x8714a775e3e95c78,0x65acfaec34810a72 , // 227  error =  4.924169331080811e-39  = +2 ** -127.2553153269021
# 0xa8d9d1535ce3b396,0x7f1839a741a14d0e , // 228  error =  2.696415123257474e-39  = +2 ** -128.12415307865658
# 0xd31045a8341ca07c,0x1ede48111209a051 , // 229  error =  9.142117569988039e-40  = +2 ** -129.6845954230032
# 0x83ea2b892091e44d,0x934aed0aab460433 , // 230  error =  3.052855796509208e-39  = +2 ** -127.94503625602623
# 0xa4e4b66b68b65d60,0xf81da84d56178540 , // 231  error =  4.193465950914757e-39  = +2 ** -127.4870525585397
# 0xce1de40642e3f4b9,0x36251260ab9d668f , // 232  error =  5.435134568170005e-40  = +2 ** -130.43480804019993
# 0x80d2ae83e9ce78f3,0xc1d72b7c6b42601a , // 233  error =  4.193465950914757e-39  = +2 ** -127.4870525585397
# 0xa1075a24e4421730,0xb24cf65b8612f820 , // 234  error =  1.857496354692193e-39  = +2 ** -128.66183632110713
# 0xc94930ae1d529cfc,0xdee033f26797b628 , // 235  error =  1.857496354692193e-39  = +2 ** -128.66183632110713
# 0xfb9b7cd9a4a7443c,0x169840ef017da3b2 , // 236  error =  1.857496354692193e-39  = +2 ** -128.66183632110713
# 0x9d412e0806e88aa5,0x8e1f289560ee864f , // 237  error =  6.6147992142624e-40  = +2 ** -130.15142642991788
# 0xc491798a08a2ad4e,0xf1a6f2bab92a27e3 , // 238  error =  1.6182930680390023e-39  = +2 ** -128.86072280141798
# 0xf5b5d7ec8acb58a2,0xae10af696774b1dc , // 239  error =  2.383743585329212e-39  = +2 ** -128.3019666443664
# 0x9991a6f3d6bf1765,0xacca6da1e0a8ef2a , // 240  error =  4.833185240657883e-39  = +2 ** -127.28222141085762
# 0xbff610b0cc6edd3f,0x17fd090a58d32af4 , // 241  error =  2.8736319163949463e-39  = +2 ** -128.0323204218321
# 0xeff394dcff8a948e,0xddfc4b4cef07f5b1 , // 242  error =  2.8736319163949463e-39  = +2 ** -128.0323204218321
# 0x95f83d0a1fb69cd9,0x4abdaf101564f98f , // 243  error =  4.754803107687366e-39  = +2 ** -127.30581009904688
# 0xbb764c4ca7a4440f,0x9d6d1ad41abe37f2 , // 244  error =  1.7449292016194946e-39  = +2 ** -128.7520271985817
# 0xea53df5fd18d5513,0x84c86189216dc5ee , // 245  error =  1.3966311838329655e-40  = +2 ** -132.3951727049582
# 0x92746b9be2f8552c,0x32fd3cf5b4e49bb5 , // 246  error =  1.4238759849722549e-39  = +2 ** -129.0453722029382
# 0xb7118682dbb66a77,0x3fbc8c33221dc2a2 , // 247  error =  3.9650569170108826e-40  = +2 ** -130.88978222003183
# 0xe4d5e82392a40515,0xfabaf3feaa5334b , // 248  error =  2.040298160934955e-39  = +2 ** -128.526415703376
# 0x8f05b1163ba6832d,0x29cb4d87f2a7400f , // 249  error =  2.6978151486285017e-39  = +2 ** -128.12340420083586
# 0xb2c71d5bca9023f8,0x743e20e9ef511013 , // 250  error =  3.7498423289381764e-39  = +2 ** -127.64836576527627
# 0xdf78e4b2bd342cf6,0x914da9246b255417 , // 251  error =  1.2249770961949571e-39  = +2 ** -129.26244092567714
# 0x8bab8eefb6409c1a,0x1ad089b6c2f7548f , // 252  error =  4.5914640731859164e-39  = +2 ** -127.35624144362812
# 0xae9672aba3d0c320,0xa184ac2473b529b2 , // 253  error =  1.3596365752745955e-39  = +2 ** -129.1119746234814
# 0xda3c0f568cc4f3e8,0xc9e5d72d90a2741f , // 254  error =  3.0832779074939664e-39  = +2 ** -127.93073076974333
# 0x8865899617fb1871,0x7e2fa67c7a658893 , // 255  error =  1.0149083088307213e-39  = +2 ** -129.53384630656663
# 0xaa7eebfb9df9de8d,0xddbb901b98feeab8 , // 256  error =  2.1180387614511187e-39  = +2 ** -128.4724667088021
# 0xd51ea6fa85785631,0x552a74227f3ea566 , // 257  error =  2.1180387614511187e-39  = +2 ** -128.4724667088021
# 0x8533285c936b35de,0xd53a88958f872760 , // 258  error =  3.530045740805227e-39  = +2 ** -127.73550882317149
# 0xa67ff273b8460356,0x8a892abaf368f138 , // 259  error =  3.530045740805227e-39  = +2 ** -127.73550882317149
# 0xd01fef10a657842c,0x2d2b7569b0432d86 , // 260  error =  3.530045740805227e-39  = +2 ** -127.73550882317149
# 0x8213f56a67f6b29b,0x9c3b29620e29fc74 , // 261  error =  4.975940887663835e-39  = +2 ** -127.24022635371996
# 0xa298f2c501f45f42,0x8349f3ba91b47b90 , // 262  error =  3.4907641771629124e-40  = +2 ** -131.07358089833724
# 0xcb3f2f7642717713,0x241c70a936219a74 , // 263  error =  3.4907641771629124e-40  = +2 ** -131.07358089833724
# 0xfe0efb53d30dd4d7,0xed238cd383aa0111 , // 264  error =  3.4907641771629124e-40  = +2 ** -131.07358089833724
# 0x9ec95d1463e8a506,0xf4363804324a40ab , // 265  error =  2.125792374176148e-39  = +2 ** -128.46719500466662
# 0xc67bb4597ce2ce48,0xb143c6053edcd0d6 , // 266  error =  3.073374217621405e-39  = +2 ** -127.93537225875372
# 0xf81aa16fdc1b81da,0xdd94b7868e94050b , // 267  error =  1.557243268108994e-39  = +2 ** -128.91620136487361
# 0x9b10a4e5e9913128,0xca7cf2b4191c8327 , // 268  error =  2.163695647913958e-39  = +2 ** -128.4416981210937
# 0xc1d4ce1f63f57d72,0xfd1c2f611f63a3f1 , // 269  error =  3.134019455601901e-39  = +2 ** -127.90718156469796
# 0xf24a01a73cf2dccf,0xbc633b39673c8ced , // 270  error =  2.357760409451547e-39  = +2 ** -128.3177785784124
# 0x976e41088617ca01,0xd5be0503e085d814 , // 271  error =  1.736753172531263e-39  = +2 ** -128.75880296789916
# 0xbd49d14aa79dbc82,0x4b2d8644d8a74e19 , // 272  error =  1.736753172531263e-39  = +2 ** -128.75880296789916
# 0xec9c459d51852ba2,0xddf8e7d60ed1219f , // 273  error =  9.418639092733003e-40  = +2 ** -129.64160517684573
# 0x93e1ab8252f33b45,0xcabb90e5c942b504 , // 274  error =  4.121420962305152e-39  = +2 ** -127.51205387246236
# 0xb8da1662e7b00a17,0x3d6a751f3b936244 , // 275  error =  5.158793442438175e-41  = +2 ** -133.83201820809674
# 0xe7109bfba19c0c9d,0xcc512670a783ad5 , // 276  error =  5.158793442438175e-41  = +2 ** -133.83201820809674
# 0x906a617d450187e2,0x27fb2b80668b24c6 , // 277  error =  4.6098009256508445e-39  = +2 ** -127.35049125142272
# 0xb484f9dc9641e9da,0xb1f9f660802dedf7 , // 278  error =  2.52604641537589e-39  = +2 ** -128.21831455213194
# 0xe1a63853bbd26451,0x5e7873f8a0396974 , // 279  error =  2.5541003045944826e-41  = +2 ** -134.84623670672747
# 0x8d07e33455637eb2,0xdb0b487b6423e1e9 , // 280  error =  2.6927467761978864e-39  = +2 ** -128.1261171343028
# 0xb049dc016abc5e5f,0x91ce1a9a3d2cda63 , // 281  error =  1.6258644669371097e-39  = +2 ** -128.8539887021286
# 0xdc5c5301c56b75f7,0x7641a140cc7810fc , // 282  error =  2.479370314345731e-39  = +2 ** -128.2452219347207
# 0x89b9b3e11b6329ba,0xa9e904c87fcb0a9e , // 283  error =  5.2105890260533196e-39  = +2 ** -127.17374923080341
# 0xac2820d9623bf429,0x546345fa9fbdcd45 , // 284  error =  3.025614056687249e-39  = +2 ** -127.9579677295806
# 0xd732290fbacaf133,0xa97c177947ad4096 , // 285  error =  2.1516240689408207e-39  = +2 ** -128.44976966790404
# 0x867f59a9d4bed6c0,0x49ed8eabcccc485e , // 286  error =  3.550008049335106e-39  = +2 ** -127.72737340480033
# 0xa81f301449ee8c70,0x5c68f256bfff5a75 , // 287  error =  1.3125936807042494e-39  = +2 ** -129.16277530802697
# 0xd226fc195c6a2f8c,0x73832eec6fff3112 , // 288  error =  4.17627933251907e-40  = +2 ** -130.81490558498456
# 0x83585d8fd9c25db7,0xc831fd53c5ff7eac , // 289  error =  4.713463521023151e-39  = +2 ** -127.31840813794695
# 0xa42e74f3d032f525,0xba3e7ca8b77f5e56 , // 290  error =  1.3123889406715732e-40  = +2 ** -132.48492845387503
# 0xcd3a1230c43fb26f,0x28ce1bd2e55f35ec , // 291  error =  1.964128744849555e-39  = +2 ** -128.58130620197875
# 0x80444b5e7aa7cf85,0x7980d163cf5b81b4 , // 292  error =  4.896752506101391e-39  = +2 ** -127.26337042006858
# 0xa0555e361951c366,0xd7e105bcc3326220 , // 293  error =  2.0455448809845324e-40  = +2 ** -131.84463860397204
# 0xc86ab5c39fa63440,0x8dd9472bf3fefaa8 , // 294  error =  2.0455448809845324e-40  = +2 ** -131.84463860397204
# 0xfa856334878fc150,0xb14f98f6f0feb952 , // 295  error =  2.0455448809845324e-40  = +2 ** -131.84463860397204
# 0x9c935e00d4b9d8d2,0x6ed1bf9a569f33d4 , // 296  error =  3.8081625659247096e-39  = +2 ** -127.62610063371355
# 0xc3b8358109e84f07,0xa862f80ec4700c9 , // 297  error =  3.8081625659247096e-39  = +2 ** -127.62610063371355
# 0xf4a642e14c6262c8,0xcd27bb612758c0fb , // 298  error =  3.039392842655108e-39  = +2 ** -127.9514125448248
# 0x98e7e9cccfbd7dbd,0x8038d51cb897789d , // 299  error =  3.654408621270789e-39  = +2 ** -127.68555774126649
# 0xbf21e44003acdd2c,0xe0470a63e6bd56c4 , // 300  error =  2.6703833754856995e-39  = +2 ** -128.138148822287
# 0xeeea5d5004981478,0x1858ccfce06cac75 , // 301  error =  2.6703833754856995e-39  = +2 ** -128.138148822287
# 0x95527a5202df0ccb,0xf37801e0c43ebc9 , // 302  error =  2.040607218183242e-39  = +2 ** -128.52619718551347
# 0xbaa718e68396cffd,0xd30560258f54e6bb , // 303  error =  1.0329653664993102e-39  = +2 ** -129.50840381660484
# 0xe950df20247c83fd,0x47c6b82ef32a206a , // 304  error =  1.8390788478464558e-39  = +2 ** -128.67621236606743
# 0x91d28b7416cdd27e,0x4cdc331d57fa5442 , // 305  error =  5.492972776910229e-40  = +2 ** -130.41953665359512
# 0xb6472e511c81471d,0xe0133fe4adf8e953 , // 306  error =  2.6129477899397153e-39  = +2 ** -128.1695174025652
# 0xe3d8f9e563a198e5,0x58180fddd97723a7 , // 307  error =  1.3656717524128445e-40  = +2 ** -132.4275130308074
# 0x8e679c2f5e44ff8f,0x570f09eaa7ea7649 , // 308  error =  3.438407994839192e-39  = +2 ** -127.7734549582321
# 0xb201833b35d63f73,0x2cd2cc6551e513db , // 309  error =  2.381818932567862e-39  = +2 ** -128.30313195785658
# 0xde81e40a034bcf4f,0xf8077f7ea65e58d2 , // 310  error =  3.227090182384926e-39  = +2 ** -127.86496180550259
# 0x8b112e86420f6191,0xfb04afaf27faf783 , // 311  error =  1.874656182677623e-39  = +2 ** -128.64856967514754
# 0xadd57a27d29339f6,0x79c5db9af1f9b564 , // 312  error =  2.9566033824434654e-39  = +2 ** -127.99125497644526
# 0xd94ad8b1c7380874,0x18375281ae7822bd , // 313  error =  2.9566033824434654e-39  = +2 ** -127.99125497644526
# 0x87cec76f1c830548,0x8f2293910d0b15b6 , // 314  error =  2.2641571745933264e-39  = +2 ** -128.37622158910887
# 0xa9c2794ae3a3c69a,0xb2eb3875504ddb23 , // 315  error =  4.83293094728811e-41  = +2 ** -133.92615350863437
# 0xd433179d9c8cb841,0x5fa60692a46151ec , // 316  error =  9.346604555210592e-40  = +2 ** -129.652681439161
# 0x849feec281d7f328,0xdbc7c41ba6bcd334 , // 317  error =  3.770920122875229e-39  = +2 ** -127.6402791095421
# 0xa5c7ea73224deff3,0x12b9b522906c0801 , // 318  error =  3.770920122875229e-39  = +2 ** -127.6402791095421
# 0xcf39e50feae16bef,0xd768226b34870a01 , // 319  error =  2.863317029321895e-39  = +2 ** -128.03750828478996
# 0x81842f29f2cce375,0xe6a1158300d46641 , // 320  error =  5.0415644538498973e-39  = +2 ** -127.22132421299624
# 0xa1e53af46f801c53,0x60495ae3c1097fd1 , // 321  error =  3.8798324941016293e-39  = +2 ** -127.59920133302603
# 0xca5e89b18b602368,0x385bb19cb14bdfc5 , // 322  error =  2.950446926303015e-39  = +2 ** -127.9942621937517
# 0xfcf62c1dee382c42,0x46729e03dd9ed7b6 , // 323  error =  2.2069384720641233e-39  = +2 ** -128.41314929178043
# 0x9e19db92b4e31ba9,0x6c07a2c26a8346d2 , // 324  error =  3.39655199884635e-39  = +2 ** -127.79112475959515
# error_max =  5.7983803233725144e-39  = +2 ** -127.01954573584383

# %% [markdown]
# It can be concluded that the error range is:
# $$
# error \in [0,2^{-127})
# $$

# %% [markdown]
# The actual value obtained through the lookup table is `pow10_lut * 2**(math.floor(i*math.log2(10)) - 127)`.
# Suppose `pow10_lut` is a 128-bit value obtained through the lookup table at index -k-1.
# $$
# \begin{align*}
# pow10 = &pow10\_lut \cdot 2^{math.floor(i*math.log2(10)) - 127} \\
# pow10 = &pow10\_lut \cdot 2^{math.floor((-k-1)*math.log2(10)) - 127} \\
# pow10 = &pow10\_lut \cdot 2^{\lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 } \\
# \end{align*}
# $$

# %% [markdown]
# The calculation of $v \cdot 10^{-k-1}$ can be approximately equal to the following expression.
# $$
# \begin{align*}
# &v \cdot 10^{-k-1} \\
# \approx &v \cdot pow10\\
# = &c \cdot 2^q \cdot pow10\_lut \cdot 2^{\lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 }\\
# = &c \cdot pow10\_lut \cdot 2^{q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 } \\
# \end{align*}
# $$
# `c` is valid at most only the lower 53 bits. `pow10_lut` is valid for a total of 128 bits. So `c*pow10_lut` has a maximum of 53+128=181 bits of valid values.
# Because there is:
# $$
# \begin{align*}
# v \cdot 10^{-k-1} = m + n
# \end{align*}
# $$
# Then $n$ can be represented by the low   $ -(q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 )$   bits of `c*pow10_lut`.
# $ q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 < 0 $ always holds true.
# $$
# \begin{align*}
# m &= (c \cdot pow10\_lut) >>  -(q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 )\\
# n_r &= ((c \cdot pow10\_lut) \& (2^{-(q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 )} - 1)) \cdot 2^{-(q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 )}\\
# \end{align*}
# $$
# Suppose $ h = q + \lfloor (-k-1)\cdot\log_2(10)\rfloor $.Calculate the range of h.

# %%
import math
h_min = 100
h_max = -100
h_regular_min = 100
h_regular_max = -100
h_irregular_min = 100
h_irregular_max = -100
for q in range(-1074,972):
    k_regular = math.floor(q*math.log10(2))
    k_irregular = math.floor(q*math.log10(2) - math.log10(4/3))
    h_regular = q + math.floor((-k_regular-1)*math.log2(10))
    h_irregular = q + math.floor((-k_irregular-1)*math.log2(10))
    h_regular_min = min(h_regular_min, h_regular)
    h_regular_max = max(h_regular_max, h_regular)
    h_irregular_min = min(h_irregular_min, h_irregular)
    h_irregular_max = max(h_irregular_max, h_irregular)
    h_min = min(h_min, h_regular, h_irregular)
    h_max = max(h_max, h_regular, h_irregular)
print("h_regular range:",h_regular_min,h_regular_max) #[-4,-1]
print("h_irregular range:",h_irregular_min,h_irregular_max) #[-3,0]
print("h range:",h_min,h_max) #[-4,0]
# Out:
# h_regular range: -4 -1
# h_irregular range: -3 0
# h range: -4 0

# %% [markdown]
# The range of $ q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 $ is $ [-4-127, 0-127] $.
# $$
# q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 \in [-131, -127]
# $$

# %%
const int offset = 6;
int get_e10 = -1 - k;
int h = q + ((get_e10 * 217707) >> 16);
u128 cb = c << (h + (1 + offset));

# %% [markdown]
# For performance reasons, first shift `c` to the left by `h + 7` bits, and `m` can be quickly obtained from the calculation result.
# `c << (h + 7)` will not cause an overflow. Since the high 11 bits of `c` are all 0, it must be true that `h + 7 < 11`.
# $$
# \begin{align*}
# m &= (c \cdot pow10\_lut) >>  -(q + \lfloor (-k-1)\cdot\log_2(10)\rfloor - 127 )\\
# m &= (c \cdot pow10\_lut) >>  -(h - 127 )\\
# m &= (c \cdot pow10\_lut) >>  (127 - h)\\
# m &= ( (c << (h+7))  \cdot pow10\_lut) >>  (127 + 7)\\
# m &= ( (c << (h+7))  \cdot pow10\_lut) >>  (128 + 6)\\
# \end{align*}
# $$
# The c*pow10_lut can be regarded as u64 * u128, and the result is u192. Only the high 128 bits are needed, which can be represented by `hi128`.

# %%
u128 hi128 = (cb * p10[0] + ((cb * p10[1]) >> 64));

# %% [markdown]
# Therefore, we have:
# $$
# \begin{align*}
# hi128 = ( (c << (h+7))  \cdot pow10\_lut) >> 64
# \end{align*}
# $$
# Therefore, m can be expressed as:
# $$
# \begin{align*}
# m &= ( (c << (h+7))  \cdot pow10\_lut) >>  (128 + 6)\\
# &= hi128 >> (64+6)\\
# &= hi128 >> (64+offset)
# \end{align*}
# $$
# Therefore, `ten = 10m` can be calculated as follows.

# %%
u64 ten = ( hi128 >> (offset + 64) ) * 10; // == 10*m

# %% [markdown]
# The value of $\lfloor 2^{64}\cdot n_r \rfloor$ can be calculated using the following code. Only the high 64-bit value of the decimal part is required.

# %%
u64 dot_one = hi128 >> offset;

# %% [markdown]
# In fact, the high `64-6=58` bits of hi128 can be represented as $m$, and the low `64+6=70` bits can be represented as $ n_r $.
# Shift `hi128` to the right by `6` bits, and take the lower `64` bits to obtain the value of $\lfloor 2^{64}\cdot n_r \rfloor$ .
#
#
# The paper has already demonstrated that the value of $one$ can be determined by using the following expression to check whether it is 0 or 10.
# $$
#   \begin{align*}
#     float:\left\{ \begin{array}{c}
#       \text{if}\,\,\lfloor 2^{q+35}\cdot 10^{-k-1} \rfloor +even>\lfloor 2^{36}\cdot n_r \rfloor :one=0\\
#       \text{if}\,\,\lfloor 2^{q+35}\cdot 10^{-k-1} \rfloor +even>2^{36}-1-\lfloor 2^{36}\cdot n_r \rfloor :one=10\\
#     \end{array} \right. \\
#     double:\left\{ \begin{array}{c}
#       \text{if}\,\,\lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor +even>\lfloor 2^{64}\cdot n_r \rfloor :one=0\\
#       \text{if}\,\,\lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor +even>2^{64}-1-\lfloor 2^{64}\cdot n_r \rfloor :one=10\\
#     \end{array} \right.
#   \end{align*}
# $$
# Let's only discuss the double part.
# The expression $\lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor $ can be calculated from the lookup table.
# This can be proved by the following Python code.

# %%
# float
import math

FLOAT = 0
min_float_q = -149
max_float_q = 104

DOUBLE = 1
min_double_q = -1074
max_double_q = 971

log2_10 = math.log2(10)

xjb32_pow10_lut = {} # length = 44 - (-32) + 1 = 77
xjb64_pow10_lut = {} # length = 323 - (-293) + 1 = 617

def generate_xjb32_lut():
    for i in range(-31-1,46-1,1):
        e10 = abs(i)
        e2 = abs(math.floor(i*log2_10) - 63)
        num = 0
        round_up = 0 if(i>=0 and i<=27) else 1
        if(i<0):
            num = (2**e2//10**e10)
        elif(i >= 20):
            num = 10**e10//2**e2
        else:
            num = 10**e10*2**e2
        result = num + round_up
        #print(hex(result),", //",i,end='\n')
        xjb32_pow10_lut[i+31+1] = result
    print("generate xjb32 lut finish:")
def generate_xjb64_lut():
    
    BIT = 128 - 1 ## 127
    ans = 0 ## 39
    i=0
    while 1:
        if(i*log2_10>=BIT):
            ans=i
            break
        i=i+1
    #print("ans = ",ans)
    for i in range(-292-1,325-1,1):
        e10 = abs(i)
        e2 = abs(math.floor(i*log2_10) - BIT)
        num=0
        round_up = 0
        if(i<0):         
            num = 2**e2//10**e10
            round_up = 1
        elif(i >= ans):
            num = 10**e10//2**e2
            round_up = 0 if(num * (2**e2) == 10**e10) else 1
        else:
            num = 10**e10*2**e2
        result = num + round_up
        xjb64_pow10_lut[i+292+1] = result
    print("generate xjb64 lut finish:")
def check_float():
    min_q = min_float_q
    max_q = max_float_q + 1
    print("checking Float:")
    all_right=1
    for q in range(min_q, max_q):  # [min_q,max_q-1] : { float:[-149, 104] ; double:[-1074, 971]; }
        k = math.floor(q * math.log10(2))
        h = q + math.floor((-k-1) * math.log2(10))
        offset = 28 - h
        A = q - k + 34
        B = k + 1
        # 2**(q+35) * 10**(-k-1) = 2**(q-k+34) * 5**(k+1)
        # x = target = 2**A * 5**(-B)
        P = Q = 1
        if(A>=0):
            P*=2**A
        else:
            Q*=2**(-A)
        if(B>=0):
            Q*=5**B
        else:
            P*=5**(-B)
        left = P//Q  # floor(P/Q)
        right = ( (xjb32_pow10_lut[(-k-1) + 31 + 1]) >> offset)  # xjb32_pow10_lut index: [0,76] for i in [-32,44]
        if(left != right):
            all_right=0
            print("mismatch q =",q,"k =",k,"A =",A,"B =",B,"-k-1 =",-k-1)
            print("left  =",left)
            print("right =",right)
            return
    if(all_right == 1):
        print("check float all right!")
def check_double():
    min_q = min_double_q
    max_q = max_double_q + 1
    print("checking Double:")
    all_right=1
    for q in range(min_q, max_q):  # [min_q,max_q-1] : { float:[-149, 104] ; double:[-1074, 971]; }
        k = math.floor(q * math.log10(2))
        h = q + math.floor((-k-1) * math.log2(10))
        offset = 64 - h
        A = q - k + 62
        B = k + 1
        # 2**(q+63) * 10**(-k-1) = 2**(q-k+62) * 5**(k+1)
        # x = target = 2**A * 5**(-B)
        P = Q = 1
        if(A>=0):
            P*=2**A
        else:
            Q*=2**(-A)
        if(B>=0):
            Q*=5**B
        else:
            P*=5**(-B)
        left = P//Q  # floor(P/Q)
        right = ( (xjb64_pow10_lut[(-k-1) + 292 + 1]) >> offset)  # xjb64_pow10_lut index: [0,617] for i in [-293,323]
        if(left != right):
            all_right = 0
            print("mismatch q =",q,"k =",k,"A =",A,"B =",B,"-k-1 =",-k-1)
            print("left  =",left)
            print("right =",right)
            return
    if(all_right == 1):
        print("check double all right!")

if __name__ == "__main__":

    generate_xjb32_lut()
    generate_xjb64_lut()

    check_float()
    check_double()
# Out:
# generate xjb32 lut finish:
# generate xjb64 lut finish:
# checking Float:
# check float all right!
# checking Double:
# check double all right!

# %% [markdown]
# Therefore, the value of $ \lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor + even $ can be calculated using the following C code.

# %%
u64 half_ulp = (p10[0] >> (-h)) + ((c + 1) & 1) ;

# %% [markdown]
# Therefore, for the following calculation process, it can be equivalently represented by the following C code.
# $$
#   \begin{align*}
#     double:\left\{ \begin{array}{c}
#       \text{if}\,\,\lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor +even>\lfloor 2^{64}\cdot n_r \rfloor :one=0\\
#       \text{if}\,\,\lfloor 2^{q+63}\cdot 10^{-k-1} \rfloor +even>2^{64}-1-\lfloor 2^{64}\cdot n_r \rfloor :one=10\\
#     \end{array} \right.
#   \end{align*}
# $$

# %%
one = (half_ulp > dot_one) ? 0 : one;
one = (half_ulp  > ~0 - dot_one) ? 10 : one;

# %% [markdown]
# Here, `~0` is equal to `2**64 - 1` or `18446744073709551615` in decimal or $ 2^{64} - 1 $. This is the largest possible integer that can be represented by a 64-bit unsigned integer.

# %% [markdown]
# The paper explains that whether n equals 0.25 can be calculated using the following expression.
# $$
# \begin{align*}
#     double:n=0.25\,\text{if}\,\,\lfloor 2^{64}\cdot n_r \rfloor =2^{62}
#     \\
#     double:n \ne 0.25\,\text{if}\,\,\lfloor 2^{64}\cdot n_r \rfloor \ne 2^{62}
#   \end{align*}
# $$
# Or it can be equivalent to the following C code.

# %%
dot_one == (1ull << 62)

# %% [markdown]
# The paper explains that "one" can be calculated using the following expression.
# $$
#   \begin{align*}
# double:one=\lfloor \frac{\lfloor 2^{64}\cdot n_r \rfloor}{2^{64}}\cdot 10+\left( n=0.25 \right) ?0:\left( 2^{-1}+\frac{6}{2^{64}} \right) \rfloor
#   \end{align*}
# $$
# Or it can be equivalent to the following C code. The two methods are equivalent.

# %%
u64 offset_num = (dot_one == (1ull << 62)) ? 0 : (1ull<<63) + 6 ;
u64 one = (dot_one * (u128)10 + offset_num ) >> 64 ;

# %%
u64 one = ((dot_one * (u128)10) >> 64)  + ( (u64)(dot_one * (u128)10) > ((dot_one == (1ull << 62)) ? ~0 : 0x7ffffffffffffff9ull) ) ;

# %% [markdown]
# The return value is { d = ten + one , k}, which represents the actual value of $d \cdot 10^k$.

# %%
*dec = ten + one;
*e10 = k;

# %% [markdown]
# The introduction process of irregular numbers has been omitted because irregular floating-point numbers can be tested through exhaustive methods.
# Please refer to the `main.cpp/check_double()` function.
# This function also proves the 10 specific values mentioned in the following paper.
# Floating-point numbers are represented in hexadecimal.
# $$
#   \begin{align*}
#     0xd17c0747bd76fa1&,\\
#     0xd27c0747bd76fa1&,\\
#     0x4d73de005bd620df&,\\
#     0x4d83de005bd620df&,\\
#     0x4d93de005bd620df&,
#   \end{align*}
# $$
# $$
#   \begin{align*}
#     0x612491daad0ba280&,\\
#     0x6159b651584e8b20&,\\
#     0x619011f2d73116f4&,\\
#     0x61c4166f8cfd5cb1&,\\
#     0x61d4166f8cfd5cb1&,
#   \end{align*}
# $$
